# %%
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup
import json
import csv
from datetime import datetime

# %%
def get_lrclib_lyrics(artist, track):
    url = f"https://lrclib.net/api/get?artist_name={artist}&track_name={track}"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        return data
    else:
        return "Lyrics not found."

# %%
def get_timestamped_lyrics(song):
    file_path = "/Users/alicemao/Downloads/"+ song +" official_times.srt"
    try:
        with open(file_path, 'r') as f:
            raw_sub = f.read()
        return raw_sub
    except FileNotFoundError:
        return FileNotFoundError

# %%
def convertSecondsToMinutes(duration):
    minutes = int(duration/60)
    seconds = int(duration) % 60
    tenths = int(duration % 1 *10)
    return f"{minutes:02}:{seconds:02}.{tenths:02}"

# %%
def getDelta(line, replaceChar):
    time_format = "%M:%S:%f"

    start = datetime.strptime(line['start'].replace(replaceChar, ':'), time_format)
    end = datetime.strptime(line['end'].replace(replaceChar, ':'), time_format)

    delta = str(end-start)
    pattern = r"\d{1}:(\d{2}:\d{2}(?:\.\d{2})?)"
    delta = re.findall(pattern, delta)[0]

    if "." not in delta:
        delta += ".00"
    
    delta = delta.replace('.', ':')
    return delta

# %%
def parse_and_normalize_synced_lyrics(synced_lyrics, officialORlrclib, duration):
    pattern = ''
    
    if officialORlrclib == 'official':
        pattern = r"\d{2}:(\d{2}:\d{2},\d{2})\d{1} --> \d{2}:(\d{2}:\d{2},\d{2})\d{1}\s*(.+)"
    else:
        pattern = r"\[(\d{2}:\d{2}\.\d{2})\]\s*(.*?)(?=\[|$)"
        synced_lyrics = synced_lyrics.replace('\n', '')

    parsed_synced_lyrics = re.findall(pattern, synced_lyrics)


    new_synced_lyrics = []
    # change all commas to . so that it all matches
    if officialORlrclib == 'official':
        for line in parsed_synced_lyrics:

            start = line[0].replace(',', ':')
            end = line[1].replace(',', ':')

            newLine = {'start': start, 'end': end, 'lyric': line[2]}
            newLine["delta"] = getDelta(newLine, ',')

            new_synced_lyrics.append(newLine)
    # Add "end" for each line
    else: 
        for i, line in enumerate(parsed_synced_lyrics):
            lyric = line[1]
            start = line[0]
            end = ''

            if lyric == '':
                continue

            if i + 1 >= len(synced_lyrics):
                end = convertSecondsToMinutes(duration)
            else:
                end = parsed_synced_lyrics[i+1][0]

            newLine = {'start': start, 'end': end, 'lyric': lyric}
            newLine["delta"] = getDelta(newLine, '.')

            new_synced_lyrics.append(newLine)

    return new_synced_lyrics

# %%
def get_synced_lyrics(artist, song):

    lrclib_results = get_lrclib_lyrics(artist, song)


    if lrclib_results == 'Lyrics not found.':
        print("NOT FOUND")
        return
    print('lrclib_results success')

    synced_lyrics_raw = ''
    officialORlrclib = ''

    get_timestamp = get_timestamped_lyrics(song)
    if get_timestamp is FileNotFoundError:
        synced_lyrics_raw = lrclib_results['syncedLyrics']
        officialORlrclib = 'lrclib'
    else:
        synced_lyrics_raw = get_timestamp
        officialORlrclib = 'official'

    print('timestamp success', officialORlrclib)

    synced_lyrics = parse_and_normalize_synced_lyrics(synced_lyrics_raw, officialORlrclib, lrclib_results['duration'])
    lrclib_results['syncedLyrics'] = synced_lyrics
    
    return lrclib_results

# %%
def get_soup(song):
    url_path = "./json/urls.json"

    with open(url_path, 'r') as file:
        all_urls = json.load(file)

    url = ''
    for u in all_urls:
        if u['name'] == song:
            url = u['url']
            print("url found:", url)

    response = requests.get(url)

    soup = BeautifulSoup(response.text, 'html.parser')
    soup = soup.body
    return soup

# %%
def clean_main_body_html(main_lyrics_body):
    html_input = main_lyrics_body

    ungrouped_span = []
    #get the first few ungrouped spans
    final_span = ''
    for line in html_input:
        if line.name == 'span':
            ungrouped_span.append(line)

        elif line.name == 'p':
            print(ungrouped_span)
            if len(ungrouped_span) == 1:
                final_span = f"<p>{ungrouped_span[0]}</p>"
            elif len(ungrouped_span) > 1:
                final_span = f"<p>{'<br>'.join(ungrouped_span)}</p>"
            break
        
    for line in html_input:
        if line.name == 'p':
            all_spans = line.findAll('span')
            new_spans = []
            for s in all_spans:
                style = s.get('style')
                lines = s.get_text(separator="|", strip=True).split("|")
                for line in lines:
                    new_spans.append(f'<span style="{style}">{line}</span>')
            final_span += f"<p>{'<br>'.join(new_spans)}</p>"

    new_html = BeautifulSoup(final_span, 'html.parser')
    print(new_html.prettify())
    return new_html

# %%
def get_color_lyrics_with_container(soup):
    body = soup.find("div", class_="wp-block-group__inner-container is-layout-flow wp-block-group-is-layout-flow")

    song_header = body.div
    color_key = song_header.find_next_sibling('p')
    spacing = color_key.find_next_sibling('div')
    main_lyrics_body = spacing.find_next_sibling('div')
    main_lyrics_body = main_lyrics_body.find_all("div", class_="wp-block-group__inner-container is-layout-flow wp-block-group-is-layout-flow")[1]

    return {"color_key": color_key, "main_lyrics_body": main_lyrics_body}

# %%
def get_color_lyrics_with_table(soup):
    body = soup.findAll("tr")

    song_header = body[1]
    main_lyrics_body = body[3].findAll("td")[1]
    color_key = song_header.find('td')

    main_lyrics_body = clean_main_body_html(main_lyrics_body)
    
    return {"song_header": song_header, "color_key": color_key, "main_lyrics_body": main_lyrics_body}

# %%
def normalize_lyrics(text):
    text = "".join(text.split())
    text = re.sub(r'[\n\(]', ' ', text)
    text = re.sub(r'[^\w\s가-힣]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    print(text)
    return text

# %%
# print('song_header', song_header)
# print('color_key', color_key)
# print('spacing', spacing)
# print('main_lyrics_body', main_lyrics_body)

# %%
def get_color_key(color_key):
    colors = color_key.find_all('span')
    print(colors)
    color_coded_key = {}
    members = []

    for c in colors:
        style = c['style']
        hex = style.split('#')[1]
        name = c.text

        color_coded_key.update({hex: name})
        members.append(name)
    return color_coded_key

# %%
def get_colored_lyrics(lyrics, color_coded_key):

    for br in lyrics.find_all("br"):
        br.decompose()
    
    colored_lyrics = []
    section_num = 0
    line_num = 0
    member = ''

    span_lyrics_html = lyrics.find_all('span', recursive=False)
    # print(span_lyrics_html)

    for s in span_lyrics_html:
        text = normalize_lyrics(s.text)
        if text:
            hex = s['style'].split('#')[1]
            if hex in color_coded_key:
                member = color_coded_key[hex]
            else:
                print("member")
            colored_lyrics.append({'member': member, 'lyric':text, 'section': section_num, 'line': line_num})
            line_num += 0


    colored_lyrics_html = lyrics.find_all('p')
    for c in colored_lyrics_html:
        line_num = 0
        for line in c:
            text = normalize_lyrics(line.text)
            if text:
                if line.name == 'span':
                    hex = line['style'].split('#')[1]
                    if hex in color_coded_key:
                        member = color_coded_key[hex]
                    else:
                        member = "all"
                colored_lyrics.append({'member': member, 'lyric':text, 'section': section_num, 'line': line_num})
                line_num += 1
        section_num += 1
    return colored_lyrics

# %%
def combine_lines(longer_line, shorter_lines, longer_line_is_official):
    index = 0
    line = ''
    found = False
    index_found = 0

    # print('combine', longer_line, shorter_lines)
    while longer_line and index < len(shorter_lines):
        shorter_line = shorter_lines[index]
        shorter_norm = normalize_lyrics(shorter_line['lyric'].lower())

        if shorter_norm in longer_line:
            longer_line = longer_line.replace(shorter_norm, '', 1).strip()

            if not longer_line_is_official:
                line += (shorter_line['lyric'] + ' ')

            index_found += 1
            if longer_line == '':
                found = True
                break
        index += 1
          
    if longer_line_is_official:
        line = longer_line
    line.strip()

    return {'index': index + 1, 'line': line, 'found': found}

# %%
def get_synced_and_assigned_lyrics(colored_lyrics, synced_lyrics):
    colored_index = 0
    synced_index = 0

    synced_and_assigned_lyrics = []

    while colored_index < len(colored_lyrics) and synced_index < len(synced_lyrics):
        print(colored_lyrics[colored_index], synced_lyrics[synced_index])

        colored_line = colored_lyrics[colored_index]
        synced_line = synced_lyrics[synced_index]

        final_line = colored_line.copy()

        # print(final_line)
        colored_norm = normalize_lyrics(colored_line['lyric'].lower())
        synced_norm = normalize_lyrics(synced_line['lyric'].lower())


        combined_results = {}
        
        if colored_norm == synced_norm:
            final_line['start'] = synced_line['start']
            final_line['end'] = synced_line['end']
            final_line['delta'] = synced_line['delta']

            colored_index += 1
            synced_index += 1
        else:
            check_further = 5

            if len(synced_norm) > len(colored_norm):
                if check_further + colored_index >= len(colored_lyrics):
                    check_further = len(colored_lyrics) - check_further - 1

                new_colored_lines = colored_lyrics[colored_index : colored_index + check_further].copy()
                combined_results = combine_lines(synced_norm, new_colored_lines, False)

                synced_index += 1
                if combined_results['found']:
                    colored_index += combined_results['index']
                    final_line['lyric'] = combined_results['line']
                else:
                    # colored_index += 1
                    final_line['lyric'] = synced_line['lyric']
                
            else:
                if check_further + synced_index >= len(synced_lyrics):
                    check_further = len(synced_lyrics) - check_further - 1

                combined_results = combine_lines(colored_norm, synced_lyrics[synced_index:synced_index+check_further], True)

                colored_index += 1
                if combined_results['found']:
                    synced_index += combined_results['index']
                    final_line['lyric'] = combined_results['line']
                else:
                    # synced_index += 1
                    final_line['lyric'] = colored_line['lyric']
            
            
            final_line['start'] = synced_line['start']
            final_line['end'] = synced_line['end']
            final_line['delta'] = synced_line['delta']

            if not combined_results['found']:
                final_line['start'] = 'LINE NOT SYNCED'
                final_line['end'] = 'LINE NOT SYNCED'
                final_line['delta'] = 'LINE NOT SYNCED'

        synced_and_assigned_lyrics.append(final_line)
        print(colored_index, synced_index, final_line)
        print()
    return synced_and_assigned_lyrics

# %%
# Define the filename and the headers (keys from your dictionary)
def export_to_csv():
    filename = "./data/rock_with_you_line_distribution.csv"
    fields = ["member", "lyric", "section", "line", "start", "end"]

    with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fields)
        
        # Write the header row
        writer.writeheader()
        
        # Write all rows at once
        writer.writerows(synced_and_assigned_lyrics)

    print(f"Data successfully exported to {filename}")

# %%
song = "very nice"
artist = "seventeen"

meta_info = get_synced_lyrics(artist, song)
synced_lyrics = meta_info['syncedLyrics']

for s in synced_lyrics:
    print(s)
    
soup = get_soup(song)
# Out:
# lrclib_results success
# timestamp success lrclib
# {'start': '00:03.37', 'end': '00:07.22', 'lyric': '아침엔 모닝콜 필수던 내가', 'delta': '00:03:85'}
# {'start': '00:07.22', 'end': '00:11.29', 'lyric': '오늘은 번쩍 번쩍 눈이 떠지는가', 'delta': '00:04:07'}
# {'start': '00:11.29', 'end': '00:13.63', 'lyric': '데이트 날이라 그런지', 'delta': '00:02:34'}
# {'start': '00:13.63', 'end': '00:15.72', 'lyric': '어제 꿈도 좋은 꿈 꿨지', 'delta': '00:02:09'}
# {'start': '00:15.72', 'end': '00:17.77', 'lyric': '새 신발을 신고', 'delta': '00:02:05'}
# {'start': '00:17.77', 'end': '00:19.79', 'lyric': '현관문을 열고 나가면', 'delta': '00:02:02'}
# {'start': '00:19.79', 'end': '00:22.90', 'lyric': '오늘 날씬 너를 많이 닮아', 'delta': '00:03:11'}
# {'start': '00:22.90', 'end': '00:26.81', 'lyric': '너에게 가는 길은 꽃길이 되고', 'delta': '00:03:91'}
# {'start': '00:26.81', 'end': '00:30.92', 'lyric': '보일 듯 말듯한 네 마음 보인다면', 'delta': '00:04:11'}
# {'start': '00:30.92', 'end': '00:33.52', 'lyric': '온몸이 간질간질 두근두근', 'delta': '00:02:60'}
# {'start': '00:33.52', 'end': '00:37.00', 'lyric': '이 기분은 뭐야 어떡해', 'delta': '00:03:48'}
# {'start': '00:37.00', 'end': '00:40.99', 'lyric': '아주 NICE', 'delta': '00:03:99'}
# {'start': '00:40.99', 'end': '00:45.26', 'lyric': '아주 NICE', 'delta': '00:04:27'}
# {'start': '00:45.26', 'end': '00:48.86', 'lyric': 'NICE', 'delta': '00:03:60'}
# {'start': '00:48.86', 'end': '00:52.32', 'lyric': '아주 NICE', 'delta': '00:03:46'}
# {'start': '00:54.34', 'end': '00:55.51', 'lyric': '뭐 하나 물어볼게', 'delta': '00:01:17'}
# {'start': '00:55.51', 'end': '00:57.27', 'lyric': '꿈에서도 너가 둥둥', 'delta': '00:01:76'}
# {'start': '00:57.27', 'end': '00:59.31', 'lyric': '떠 다닐 것 같애 맞아', 'delta': '00:02:04'}
# {'start': '00:59.31', 'end': '01:00.72', 'lyric': '멋진 남자 되고파', 'delta': '00:01:41'}
# {'start': '01:00.72', 'end': '01:03.14', 'lyric': 'Fitness 끊은 것 같애 맞아', 'delta': '00:02:42'}
# {'start': '01:03.14', 'end': '01:04.64', 'lyric': '연애가 첨이라', 'delta': '00:01:50'}
# {'start': '01:04.64', 'end': '01:06.51', 'lyric': '내가 긴장할 것 같애', 'delta': '00:01:87'}
# {'start': '01:06.51', 'end': '01:09.05', 'lyric': '너가 나의 모든 의문점에 대한', 'delta': '00:02:54'}
# {'start': '01:09.05', 'end': '01:10.48', 'lyric': '정답인 것 같애', 'delta': '00:01:43'}
# {'start': '01:10.48', 'end': '01:12.23', 'lyric': '아 궁금한 게 있는데', 'delta': '00:01:75'}
# {'start': '01:12.23', 'end': '01:14.46', 'lyric': '어떻게 그리 예뻐', 'delta': '00:02:23'}
# {'start': '01:14.46', 'end': '01:16.26', 'lyric': '신호등만 건너면', 'delta': '00:01:80'}
# {'start': '01:16.26', 'end': '01:18.39', 'lyric': '맛있는 가게 있어', 'delta': '00:02:13'}
# {'start': '01:18.39', 'end': '01:19.02', 'lyric': '가자', 'delta': '00:00:63'}
# {'start': '01:19.02', 'end': '01:22.06', 'lyric': '오늘 날씨 너를 많이 닮아', 'delta': '00:03:04'}
# {'start': '01:22.06', 'end': '01:26.07', 'lyric': '너에게 가는 길은 꽃길이 되고', 'delta': '00:04:01'}
# {'start': '01:26.07', 'end': '01:30.15', 'lyric': '보일 듯 말듯한 네 마음 보인다면', 'delta': '00:04:08'}
# {'start': '01:30.15', 'end': '01:32.76', 'lyric': '온몸이 간질간질 두근두근', 'delta': '00:02:61'}
# {'start': '01:32.76', 'end': '01:38.20', 'lyric': '이 기분은 뭐야 어떡해 뭐야 어떡해', 'delta': '00:05:44'}
# {'start': '01:38.20', 'end': '01:42.27', 'lyric': '아주 NICE', 'delta': '00:04:07'}
# {'start': '01:42.27', 'end': '01:46.43', 'lyric': '아주 NICE', 'delta': '00:04:16'}
# {'start': '01:46.43', 'end': '01:50.00', 'lyric': 'NICE', 'delta': '00:03:57'}
# {'start': '01:50.00', 'end': '01:52.57', 'lyric': '아주 NICE', 'delta': '00:02:57'}
# {'start': '01:52.57', 'end': '01:57.35', 'lyric': '어떤 사람은 말하죠', 'delta': '00:04:78'}
# {'start': '01:57.35', 'end': '01:59.92', 'lyric': '연애는 연애일 뿐이라고', 'delta': '00:02:57'}
# {'start': '01:59.92', 'end': '02:01.80', 'lyric': '그걸로 끝이라고', 'delta': '00:01:88'}
# {'start': '02:01.80', 'end': '02:04.15', 'lyric': '그렇다면 시작점이 끝이 될 수 있게', 'delta': '00:02:35'}
# {'start': '02:04.15', 'end': '02:06.11', 'lyric': '너로 시작해 나로 끝낼 수 있게', 'delta': '00:01:96'}
# {'start': '02:06.11', 'end': '02:08.07', 'lyric': '맞잡은 두 손에 원처럼', 'delta': '00:01:96'}
# {'start': '02:08.07', 'end': '02:09.62', 'lyric': '우린 끝이 없네', 'delta': '00:01:55'}
# {'start': '02:09.62', 'end': '02:11.67', 'lyric': '지금 상황 FOREVER', 'delta': '00:02:05'}
# {'start': '02:11.67', 'end': '02:13.68', 'lyric': '우리 둘이 FOREVER', 'delta': '00:02:01'}
# {'start': '02:13.68', 'end': '02:16.49', 'lyric': '첫사랑은 안 이루어 진단 말은', 'delta': '00:02:81'}
# {'start': '02:16.49', 'end': '02:18.17', 'lyric': '믿지 않기로 해요', 'delta': '00:01:68'}
# {'start': '02:18.17', 'end': '02:20.70', 'lyric': '익숙함에 속아 잃지 않았으면 해', 'delta': '00:02:53'}
# {'start': '02:20.70', 'end': '02:21.73', 'lyric': '서로가', 'delta': '00:01:03'}
# {'start': '02:21.73', 'end': '02:24.12', 'lyric': '우리라는 말이 지켜질 수 있게', 'delta': '00:02:39'}
# {'start': '02:24.12', 'end': '02:27.61', 'lyric': '진지한데 뜬금없지만', 'delta': '00:03:49'}
# {'start': '02:27.61', 'end': '02:33.48', 'lyric': '뜬금없지만 오늘 난 말야', 'delta': '00:05:87'}
# {'start': '02:33.48', 'end': '02:37.30', 'lyric': '아주 NICE', 'delta': '00:03:82'}
# {'start': '02:37.30', 'end': '02:41.55', 'lyric': '아주 NICE', 'delta': '00:04:25'}
# {'start': '02:41.55', 'end': '02:45.15', 'lyric': 'NICE', 'delta': '00:03:60'}
# {'start': '02:45.15', 'end': '02:49.45', 'lyric': '아주 NICE', 'delta': '00:04:30'}
# {'start': '02:49.45', 'end': '02:53.25', 'lyric': '오늘 하루도 아주 즐거웠어요', 'delta': '00:03:80'}
# {'start': '02:53.25', 'end': '02:57.18', 'lyric': '다음 데이트도 빨리 했음 좋겠어요', 'delta': '00:03:93'}
# {'start': '02:57.18', 'end': '03:01.02', 'lyric': '집 데려다 주는 길이 너무도 짧아요', 'delta': '00:03:84'}
# {'start': '03:01.02', 'end': '03:04.28', 'lyric': '내일 이 시간에 또 만나요', 'delta': '00:03:26'}
# url found: https://colorcodedlyrics.com/2016/07/03/seventeen-very-nice-aju-nice/

# %%
html_results = []
if soup.find(('table')) != None:
    html_results = get_color_lyrics_with_table(soup)
else:
    html_results = get_color_lyrics_with_container(soup)

color_key = html_results['color_key']
main_lyrics_body = html_results['main_lyrics_body']
# Out:
# [<span style="color: #63b76c">Four tres two uno uno two</span>]
# <p>
#  <span style="color: #63b76c">
#   Four tres two uno uno two
#  </span>
# </p>
# <p>
#  <span style="color: #3d72e7">
#   아침엔 모닝콜 필수던 내가
#  </span>
#  <br/>
#  <span style="color: #3d72e7">
#   오늘은 번쩍 번쩍 눈이 떠지는가
#  </span>
#  <br/>
#  <span style="color: #c04737">
#   데이트 날이라 그런지
#  </span>
#  <br/>
#  <span style="color: #c04737">
#   어제 꿈도 좋은 꿈 꿨지
#  </span>
#  <br/>
#  <span style="color: #855fc4">
#   새 신발을 신고
#  </span>
#  <br/>
#  <span style="color: #04a497">
#   현관문을 열고 나가면
#  </span>
# </p>
# <p>
#  <span style="color: #f1ce5f">
#   오늘 날씬 너를 많이 닮아
#  </span>
#  <br/>
#  <span style="color: #f1ce5f">
#   너에게 가는 길은 꽃길이 되고
#  </span>
#  <br/>
#  <span style="color: #3d72e7">
#   보일 듯 말 듯한 니 맘 보인다면
#  </span>
#  <br/>
#  <span style="color: #04a497">
#   온몸이 간질간질 두근두근
#  </span>
#  <br/>
#  <span style="color: #df73ff">
#   이 기분은 뭐야 어떡해
#  </span>
# </p>
# <p>
#  <span style="color: #ffffff">
#   아주 Nice
#  </span>
#  <br/>
#  <span style="color: #ffffff">
#   아주 Nice
#  </span>
#  <br/>
#  <span style="color: #ffffff">
#   기분 기분 기분
#  </span>
#  <br/>
#  <span style="color: #ffffff">
#   Nice
#  </span>
#  <br/>
#  <span style="color: #ffffff">
#   아주 Nice
#  </span>
# </p>
# <p>
#  <span style="color: #63b76c">
#   Four tres two
#  </span>
# </p>
# <p>
#  <span style="color: #d962b6">
#   뭐 하나 물어볼게
#  </span>
#  <br/>
#  <span style="color: #d962b6">
#   꿈에서도 너가 둥둥
#  </span>
#  <br/>
#  <span style="color: #d962b6">
#   떠다닐 것 같애?
#  </span>
#  <br/>
#  <span style="color: #63b76c">
#   맞아
#  </span>
#  <br/>
#  <span style="color: #63b76c">
#   멋진 남자 되고파 Fitness
#  </span>
#  <br/>
#  <span style="color: #63b76c">
#   끊은 것 같애?
#  </span>
#  <br/>
#  <span style="color: #d962b6">
#   맞아
#  </span>
#  <br/>
#  <span style="color: #d962b6">
#   연애가 첨이라 내가
#  </span>
#  <br/>
#  <span style="color: #d962b6">
#   긴장할 것 같애?
#  </span>
#  <br/>
#  <span style="color: #63b76c">
#   너가 나의 모든 의문점에
#  </span>
#  <br/>
#  <span style="color: #63b76c">
#   대한 정답인 것 같애
#  </span>
# </p>
# <p>
#  <span style="color: #a1dad7">
#   Ah 궁금한 게 있는데
#  </span>
#  <br/>
#  <span style="color: #a1dad7">
#   어떻게 그리 예뻐
#  </span>
#  <br/>
#  <span style="color: #bede0d">
#   신호등만 건너면
#  </span>
#  <br/>
#  <span style="color: #bede0d">
#   맛있는 가게 있어
#  </span>
#  <br/>
#  <span style="color: #bede0d">
#   가자
#  </span>
# </p>
# <p>
#  <span style="color: #df73ff">
#   오늘 날씬 너를 많이 닮아
#  </span>
#  <br/>
#  <span style="color: #df73ff">
#   너에게 가는 길은 꽃길이 되고
#  </span>
#  <br/>
#  <span style="color: #3d72e7">
#   보일 듯 말 듯한 니 맘 보인다면
#  </span>
#  <br/>
#  <span style="color: #04a497">
#   온몸이 간질간질 두근두근
#  </span>
#  <br/>
#  <span style="color: #3d72e7">
#   이 기분은 뭐야 어떡해
#  </span>
#  <br/>
#  <span style="color: #3d72e7">
#   뭐야 어떡해
#  </span>
# </p>
# <p>
#  <span style="color: #ffffff">
#   아주 Nice
#  </span>
#  <br/>
#  <span style="color: #ffffff">
#   아주 Nice
#  </span>
#  <br/>
#  <span style="color: #ffffff">
#   기분 기분 기분
#  </span>
#  <br/>
#  <span style="color: #ffffff">
#   Nice
#  </span>
#  <br/>
#  <span style="color: #ffffff">
#   아주 Nice
#  </span>
# </p>
# <p>
#  <span style="color: #ff7d07">
#   어떤 사람은 말하죠
#  </span>
#  <br/>
#  <span style="color: #ff7d07">
#   연애는 연앨 뿐이라고
#  </span>
#  <br/>
#  <span style="color: #ff7d07">
#   그걸로 끝이라고
#  </span>
# </p>
# <p>
#  <span style="color: #4ea8d4">
#   그렇다면 시작점이
#  </span>
#  <br/>
#  <span style="color: #4ea8d4">
#   끝이 될 수 있게
#  </span>
#  <br/>
#  <span style="color: #4ea8d4">
#   너로 시작해 나로 끝낼 수 있게
#  </span>
#  <br/>
#  <span style="color: #4ea8d4">
#   맞잡은 두 손에 원처럼
#  </span>
#  <br/>
#  <span style="color: #4ea8d4">
#   (
#  </span>
#  <br/>
#  <span style="color: #4ea8d4">
#   우린 끝이 없네
#  </span>
#  <br/>
#  <span style="color: #4ea8d4">
#   )
#  </span>
#  <br/>
#  <span style="color: #855fc4">
#   맞잡은 두 손에 원처럼
#  </span>
#  <br/>
#  <span style="color: #855fc4">
#   우린 끝이 없네
#  </span>
# </p>
# <p>
#  <span style="color: #e32636">
#   지금 상황 Forever
#  </span>
#  <br/>
#  <span style="color: #e32636">
#   우리 둘이 Forever
#  </span>
#  <br/>
#  <span style="color: #e32636">
#   첫사랑은 안 이뤄진단
#  </span>
#  <br/>
#  <span style="color: #e32636">
#   말은 믿지 않기로 해요
#  </span>
#  <br/>
#  <span style="color: #04a497">
#   익숙함에 속아
#  </span>
#  <br/>
#  <span style="color: #04a497">
#   잃지 않았으면 해 서로가
#  </span>
#  <br/>
#  <span style="color: #855fc4">
#   우리라는 말이 지켜질 수 있게
#  </span>
#  <br/>
#  <span style="color: #f1ce5f">
#   진지한데 뜬금없지만
#  </span>
#  <br/>
#  <span style="color: #3d72e7">
#   뜬금없지만 Woa
#  </span>
#  <br/>
#  <span style="color: #f1ce5f">
#   오늘 난 말야
#  </span>
# </p>
# <p>
#  <span style="color: #ffffff">
#   아주 Nice
#  </span>
#  <br/>
#  <span style="color: #ffffff">
#   아주 Nice
#  </span>
#  <br/>
#  <span style="color: #ffffff">
#   기분 기분 기분
#  </span>
#  <br/>
#  <span style="color: #ffffff">
#   Nice
#  </span>
#  <br/>
#  <span style="color: #ffffff">
#   아주 Nice
#  </span>
# </p>
# <p>
#  <span style="color: #ffffff">
#   오늘 하루도 아주 즐거웠어요
#  </span>
#  <br/>
#  <span style="color: #ffffff">
#   다음 데이트도 빨리 했음 좋겠어요
#  </span>
#  <br/>
#  <span style="color: #ffffff">
#   집 데려다 주는 길이 너무도 짧아요
#  </span>
#  <br/>
#  <span style="color: #ffffff">
#   내일 이 시간에 또 만나요
#  </span>
# </p>

# %%
color_coded_key = get_color_key(color_key)
print(color_coded_key)

colored_lyrics = get_colored_lyrics(html_results['main_lyrics_body'], color_coded_key)

for c in colored_lyrics:
    print(c)
# Out:
# [<span style="color: #4ea8d4">S. Coups</span>, <span style="color: #e32636">Jeonghan</span>, <span style="color: #df73ff">Joshua</span>, <span style="color: #bede0d">Jun</span>, <span style="color: #c04737">Hoshi</span>, <span style="color: #855fc4">Wonwoo</span>, <span style="color: #ff7d07">Woozi</span>, <span style="color: #3d72e7">DK</span>, <span style="color: #04a497">Mingyu</span>, <span style="color: #a1dad7">The8</span>, <span style="color: #f1ce5f">Seungkwan</span>, <span style="color: #63b76c">Vernon</span>, <span style="color: #d962b6">Dino</span>]
# {'4ea8d4': 'S. Coups', 'e32636': 'Jeonghan', 'df73ff': 'Joshua', 'bede0d': 'Jun', 'c04737': 'Hoshi', '855fc4': 'Wonwoo', 'ff7d07': 'Woozi', '3d72e7': 'DK', '04a497': 'Mingyu', 'a1dad7': 'The8', 'f1ce5f': 'Seungkwan', '63b76c': 'Vernon', 'd962b6': 'Dino'}
# {'member': 'Vernon', 'lyric': 'Four tres two uno uno two', 'section': 0, 'line': 0}
# {'member': 'DK', 'lyric': '아침엔 모닝콜 필수던 내가', 'section': 1, 'line': 0}
# {'member': 'DK', 'lyric': '오늘은 번쩍 번쩍 눈이 떠지는가', 'section': 1, 'line': 1}
# {'member': 'Hoshi', 'lyric': '데이트 날이라 그런지', 'section': 1, 'line': 2}
# {'member': 'Hoshi', 'lyric': '어제 꿈도 좋은 꿈 꿨지', 'section': 1, 'line': 3}
# {'member': 'Wonwoo', 'lyric': '새 신발을 신고', 'section': 1, 'line': 4}
# {'member': 'Mingyu', 'lyric': '현관문을 열고 나가면', 'section': 1, 'line': 5}
# {'member': 'Seungkwan', 'lyric': '오늘 날씬 너를 많이 닮아', 'section': 2, 'line': 0}
# {'member': 'Seungkwan', 'lyric': '너에게 가는 길은 꽃길이 되고', 'section': 2, 'line': 1}
# {'member': 'DK', 'lyric': '보일 듯 말 듯한 니 맘 보인다면', 'section': 2, 'line': 2}
# {'member': 'Mingyu', 'lyric': '온몸이 간질간질 두근두근', 'section': 2, 'line': 3}
# {'member': 'Joshua', 'lyric': '이 기분은 뭐야 어떡해', 'section': 2, 'line': 4}
# {'member': 'all', 'lyric': '아주 Nice', 'section': 3, 'line': 0}
# {'member': 'all', 'lyric': '아주 Nice', 'section': 3, 'line': 1}
# {'member': 'all', 'lyric': '기분 기분 기분', 'section': 3, 'line': 2}
# {'member': 'all', 'lyric': 'Nice', 'section': 3, 'line': 3}
# {'member': 'all', 'lyric': '아주 Nice', 'section': 3, 'line': 4}
# {'member': 'Vernon', 'lyric': 'Four tres two', 'section': 4, 'line': 0}
# {'member': 'Dino', 'lyric': '뭐 하나 물어볼게', 'section': 5, 'line': 0}
# {'member': 'Dino', 'lyric': '꿈에서도 너가 둥둥', 'section': 5, 'line': 1}
# {'member': 'Dino', 'lyric': '떠다닐 것 같애', 'section': 5, 'line': 2}
# {'member': 'Vernon', 'lyric': '맞아', 'section': 5, 'line': 3}
# {'member': 'Vernon', 'lyric': '멋진 남자 되고파 Fitness', 'section': 5, 'line': 4}
# {'member': 'Vernon', 'lyric': '끊은 것 같애', 'section': 5, 'line': 5}
# {'member': 'Dino', 'lyric': '맞아', 'section': 5, 'line': 6}
# {'member': 'Dino', 'lyric': '연애가 첨이라 내가', 'section': 5, 'line': 7}
# {'member': 'Dino', 'lyric': '긴장할 것 같애', 'section': 5, 'line': 8}
# {'member': 'Vernon', 'lyric': '너가 나의 모든 의문점에', 'section': 5, 'line': 9}
# {'member': 'Vernon', 'lyric': '대한 정답인 것 같애', 'section': 5, 'line': 10}
# {'member': 'The8', 'lyric': 'Ah 궁금한 게 있는데', 'section': 6, 'line': 0}
# {'member': 'The8', 'lyric': '어떻게 그리 예뻐', 'section': 6, 'line': 1}
# {'member': 'Jun', 'lyric': '신호등만 건너면', 'section': 6, 'line': 2}
# {'member': 'Jun', 'lyric': '맛있는 가게 있어', 'section': 6, 'line': 3}
# {'member': 'Jun', 'lyric': '가자', 'section': 6, 'line': 4}
# {'member': 'Joshua', 'lyric': '오늘 날씬 너를 많이 닮아', 'section': 7, 'line': 0}
# {'member': 'Joshua', 'lyric': '너에게 가는 길은 꽃길이 되고', 'section': 7, 'line': 1}
# {'member': 'DK', 'lyric': '보일 듯 말 듯한 니 맘 보인다면', 'section': 7, 'line': 2}
# {'member': 'Mingyu', 'lyric': '온몸이 간질간질 두근두근', 'section': 7, 'line': 3}
# {'member': 'DK', 'lyric': '이 기분은 뭐야 어떡해', 'section': 7, 'line': 4}
# {'member': 'DK', 'lyric': '뭐야 어떡해', 'section': 7, 'line': 5}
# {'member': 'all', 'lyric': '아주 Nice', 'section': 8, 'line': 0}
# {'member': 'all', 'lyric': '아주 Nice', 'section': 8, 'line': 1}
# {'member': 'all', 'lyric': '기분 기분 기분', 'section': 8, 'line': 2}
# {'member': 'all', 'lyric': 'Nice', 'section': 8, 'line': 3}
# {'member': 'all', 'lyric': '아주 Nice', 'section': 8, 'line': 4}
# {'member': 'Woozi', 'lyric': '어떤 사람은 말하죠', 'section': 9, 'line': 0}
# {'member': 'Woozi', 'lyric': '연애는 연앨 뿐이라고', 'section': 9, 'line': 1}
# {'member': 'Woozi', 'lyric': '그걸로 끝이라고', 'section': 9, 'line': 2}
# {'member': 'S. Coups', 'lyric': '그렇다면 시작점이', 'section': 10, 'line': 0}
# {'member': 'S. Coups', 'lyric': '끝이 될 수 있게', 'section': 10, 'line': 1}
# {'member': 'S. Coups', 'lyric': '너로 시작해 나로 끝낼 수 있게', 'section': 10, 'line': 2}
# {'member': 'S. Coups', 'lyric': '맞잡은 두 손에 원처럼', 'section': 10, 'line': 3}
# {'member': 'S. Coups', 'lyric': '우린 끝이 없네', 'section': 10, 'line': 4}
# {'member': 'Wonwoo', 'lyric': '맞잡은 두 손에 원처럼', 'section': 10, 'line': 5}
# {'member': 'Wonwoo', 'lyric': '우린 끝이 없네', 'section': 10, 'line': 6}
# {'member': 'Jeonghan', 'lyric': '지금 상황 Forever', 'section': 11, 'line': 0}
# {'member': 'Jeonghan', 'lyric': '우리 둘이 Forever', 'section': 11, 'line': 1}
# {'member': 'Jeonghan', 'lyric': '첫사랑은 안 이뤄진단', 'section': 11, 'line': 2}
# {'member': 'Jeonghan', 'lyric': '말은 믿지 않기로 해요', 'section': 11, 'line': 3}
# {'member': 'Mingyu', 'lyric': '익숙함에 속아', 'section': 11, 'line': 4}
# {'member': 'Mingyu', 'lyric': '잃지 않았으면 해 서로가', 'section': 11, 'line': 5}
# {'member': 'Wonwoo', 'lyric': '우리라는 말이 지켜질 수 있게', 'section': 11, 'line': 6}
# {'member': 'Seungkwan', 'lyric': '진지한데 뜬금없지만', 'section': 11, 'line': 7}
# {'member': 'DK', 'lyric': '뜬금없지만 Woa', 'section': 11, 'line': 8}
# {'member': 'Seungkwan', 'lyric': '오늘 난 말야', 'section': 11, 'line': 9}
# {'member': 'all', 'lyric': '아주 Nice', 'section': 12, 'line': 0}
# {'member': 'all', 'lyric': '아주 Nice', 'section': 12, 'line': 1}
# {'member': 'all', 'lyric': '기분 기분 기분', 'section': 12, 'line': 2}
# {'member': 'all', 'lyric': 'Nice', 'section': 12, 'line': 3}
# {'member': 'all', 'lyric': '아주 Nice', 'section': 12, 'line': 4}
# {'member': 'all', 'lyric': '오늘 하루도 아주 즐거웠어요', 'section': 13, 'line': 0}
# {'member': 'all', 'lyric': '다음 데이트도 빨리 했음 좋겠어요', 'section': 13, 'line': 1}
# {'member': 'all', 'lyric': '집 데려다 주는 길이 너무도 짧아요', 'section': 13, 'line': 2}
# {'member': 'all', 'lyric': '내일 이 시간에 또 만나요', 'section': 13, 'line': 3}

# %%
synced_and_assigned_lyrics = get_synced_and_assigned_lyrics(colored_lyrics, synced_lyrics)

print(synced_and_assigned_lyrics)
# Out:
# {'member': 'Vernon', 'lyric': 'Four tres two uno uno two', 'section': 0, 'line': 0} {'start': '00:03.37', 'end': '00:07.22', 'lyric': '아침엔 모닝콜 필수던 내가', 'delta': '00:03:85'}
# fourtrestwounounotwo
# 아침엔모닝콜필수던내가
# 아침엔모닝콜필수던내가
# 오늘은번쩍번쩍눈이떠지는가
# 데이트날이라그런지
# 어제꿈도좋은꿈꿨지
# 새신발을신고
# 1 0 {'member': 'Vernon', 'lyric': 'Four tres two uno uno two', 'section': 0, 'line': 0, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'DK', 'lyric': '아침엔 모닝콜 필수던 내가', 'section': 1, 'line': 0} {'start': '00:03.37', 'end': '00:07.22', 'lyric': '아침엔 모닝콜 필수던 내가', 'delta': '00:03:85'}
# 아침엔모닝콜필수던내가
# 아침엔모닝콜필수던내가
# 2 1 {'member': 'DK', 'lyric': '아침엔 모닝콜 필수던 내가', 'section': 1, 'line': 0, 'start': '00:03.37', 'end': '00:07.22', 'delta': '00:03:85'}
#
# {'member': 'DK', 'lyric': '오늘은 번쩍 번쩍 눈이 떠지는가', 'section': 1, 'line': 1} {'start': '00:07.22', 'end': '00:11.29', 'lyric': '오늘은 번쩍 번쩍 눈이 떠지는가', 'delta': '00:04:07'}
# 오늘은번쩍번쩍눈이떠지는가
# 오늘은번쩍번쩍눈이떠지는가
# 3 2 {'member': 'DK', 'lyric': '오늘은 번쩍 번쩍 눈이 떠지는가', 'section': 1, 'line': 1, 'start': '00:07.22', 'end': '00:11.29', 'delta': '00:04:07'}
#
# {'member': 'Hoshi', 'lyric': '데이트 날이라 그런지', 'section': 1, 'line': 2} {'start': '00:11.29', 'end': '00:13.63', 'lyric': '데이트 날이라 그런지', 'delta': '00:02:34'}
# 데이트날이라그런지
# 데이트날이라그런지
# 4 3 {'member': 'Hoshi', 'lyric': '데이트 날이라 그런지', 'section': 1, 'line': 2, 'start': '00:11.29', 'end': '00:13.63', 'delta': '00:02:34'}
#
# {'member': 'Hoshi', 'lyric': '어제 꿈도 좋은 꿈 꿨지', 'section': 1, 'line': 3} {'start': '00:13.63', 'end': '00:15.72', 'lyric': '어제 꿈도 좋은 꿈 꿨지', 'delta': '00:02:09'}
# 어제꿈도좋은꿈꿨지
# 어제꿈도좋은꿈꿨지
# 5 4 {'member': 'Hoshi', 'lyric': '어제 꿈도 좋은 꿈 꿨지', 'section': 1, 'line': 3, 'start': '00:13.63', 'end': '00:15.72', 'delta': '00:02:09'}
#
# {'member': 'Wonwoo', 'lyric': '새 신발을 신고', 'section': 1, 'line': 4} {'start': '00:15.72', 'end': '00:17.77', 'lyric': '새 신발을 신고', 'delta': '00:02:05'}
# 새신발을신고
# 새신발을신고
# 6 5 {'member': 'Wonwoo', 'lyric': '새 신발을 신고', 'section': 1, 'line': 4, 'start': '00:15.72', 'end': '00:17.77', 'delta': '00:02:05'}
#
# {'member': 'Mingyu', 'lyric': '현관문을 열고 나가면', 'section': 1, 'line': 5} {'start': '00:17.77', 'end': '00:19.79', 'lyric': '현관문을 열고 나가면', 'delta': '00:02:02'}
# 현관문을열고나가면
# 현관문을열고나가면
# 7 6 {'member': 'Mingyu', 'lyric': '현관문을 열고 나가면', 'section': 1, 'line': 5, 'start': '00:17.77', 'end': '00:19.79', 'delta': '00:02:02'}
#
# {'member': 'Seungkwan', 'lyric': '오늘 날씬 너를 많이 닮아', 'section': 2, 'line': 0} {'start': '00:19.79', 'end': '00:22.90', 'lyric': '오늘 날씬 너를 많이 닮아', 'delta': '00:03:11'}
# 오늘날씬너를많이닮아
# 오늘날씬너를많이닮아
# 8 7 {'member': 'Seungkwan', 'lyric': '오늘 날씬 너를 많이 닮아', 'section': 2, 'line': 0, 'start': '00:19.79', 'end': '00:22.90', 'delta': '00:03:11'}
#
# {'member': 'Seungkwan', 'lyric': '너에게 가는 길은 꽃길이 되고', 'section': 2, 'line': 1} {'start': '00:22.90', 'end': '00:26.81', 'lyric': '너에게 가는 길은 꽃길이 되고', 'delta': '00:03:91'}
# 너에게가는길은꽃길이되고
# 너에게가는길은꽃길이되고
# 9 8 {'member': 'Seungkwan', 'lyric': '너에게 가는 길은 꽃길이 되고', 'section': 2, 'line': 1, 'start': '00:22.90', 'end': '00:26.81', 'delta': '00:03:91'}
#
# {'member': 'DK', 'lyric': '보일 듯 말 듯한 니 맘 보인다면', 'section': 2, 'line': 2} {'start': '00:26.81', 'end': '00:30.92', 'lyric': '보일 듯 말듯한 네 마음 보인다면', 'delta': '00:04:11'}
# 보일듯말듯한니맘보인다면
# 보일듯말듯한네마음보인다면
# 보일듯말듯한니맘보인다면
# 온몸이간질간질두근두근
# 이기분은뭐야어떡해
# 아주nice
# 아주nice
# 9 9 {'member': 'DK', 'lyric': '보일 듯 말듯한 네 마음 보인다면', 'section': 2, 'line': 2, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'DK', 'lyric': '보일 듯 말 듯한 니 맘 보인다면', 'section': 2, 'line': 2} {'start': '00:30.92', 'end': '00:33.52', 'lyric': '온몸이 간질간질 두근두근', 'delta': '00:02:60'}
# 보일듯말듯한니맘보인다면
# 온몸이간질간질두근두근
# 온몸이간질간질두근두근
# 이기분은뭐야어떡해
# 아주nice
# 아주nice
# nice
# 10 9 {'member': 'DK', 'lyric': '보일 듯 말 듯한 니 맘 보인다면', 'section': 2, 'line': 2, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Mingyu', 'lyric': '온몸이 간질간질 두근두근', 'section': 2, 'line': 3} {'start': '00:30.92', 'end': '00:33.52', 'lyric': '온몸이 간질간질 두근두근', 'delta': '00:02:60'}
# 온몸이간질간질두근두근
# 온몸이간질간질두근두근
# 11 10 {'member': 'Mingyu', 'lyric': '온몸이 간질간질 두근두근', 'section': 2, 'line': 3, 'start': '00:30.92', 'end': '00:33.52', 'delta': '00:02:60'}
#
# {'member': 'Joshua', 'lyric': '이 기분은 뭐야 어떡해', 'section': 2, 'line': 4} {'start': '00:33.52', 'end': '00:37.00', 'lyric': '이 기분은 뭐야 어떡해', 'delta': '00:03:48'}
# 이기분은뭐야어떡해
# 이기분은뭐야어떡해
# 12 11 {'member': 'Joshua', 'lyric': '이 기분은 뭐야 어떡해', 'section': 2, 'line': 4, 'start': '00:33.52', 'end': '00:37.00', 'delta': '00:03:48'}
#
# {'member': 'all', 'lyric': '아주 Nice', 'section': 3, 'line': 0} {'start': '00:37.00', 'end': '00:40.99', 'lyric': '아주 NICE', 'delta': '00:03:99'}
# 아주nice
# 아주nice
# 13 12 {'member': 'all', 'lyric': '아주 Nice', 'section': 3, 'line': 0, 'start': '00:37.00', 'end': '00:40.99', 'delta': '00:03:99'}
#
# {'member': 'all', 'lyric': '아주 Nice', 'section': 3, 'line': 1} {'start': '00:40.99', 'end': '00:45.26', 'lyric': '아주 NICE', 'delta': '00:04:27'}
# 아주nice
# 아주nice
# 14 13 {'member': 'all', 'lyric': '아주 Nice', 'section': 3, 'line': 1, 'start': '00:40.99', 'end': '00:45.26', 'delta': '00:04:27'}
#
# {'member': 'all', 'lyric': '기분 기분 기분', 'section': 3, 'line': 2} {'start': '00:45.26', 'end': '00:48.86', 'lyric': 'NICE', 'delta': '00:03:60'}
# 기분기분기분
# nice
# nice
# 아주nice
# 뭐하나물어볼게
# 꿈에서도너가둥둥
# 떠다닐것같애맞아
# 15 13 {'member': 'all', 'lyric': '기분 기분 기분', 'section': 3, 'line': 2, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'all', 'lyric': 'Nice', 'section': 3, 'line': 3} {'start': '00:45.26', 'end': '00:48.86', 'lyric': 'NICE', 'delta': '00:03:60'}
# nice
# nice
# 16 14 {'member': 'all', 'lyric': 'Nice', 'section': 3, 'line': 3, 'start': '00:45.26', 'end': '00:48.86', 'delta': '00:03:60'}
#
# {'member': 'all', 'lyric': '아주 Nice', 'section': 3, 'line': 4} {'start': '00:48.86', 'end': '00:52.32', 'lyric': '아주 NICE', 'delta': '00:03:46'}
# 아주nice
# 아주nice
# 17 15 {'member': 'all', 'lyric': '아주 Nice', 'section': 3, 'line': 4, 'start': '00:48.86', 'end': '00:52.32', 'delta': '00:03:46'}
#
# {'member': 'Vernon', 'lyric': 'Four tres two', 'section': 4, 'line': 0} {'start': '00:54.34', 'end': '00:55.51', 'lyric': '뭐 하나 물어볼게', 'delta': '00:01:17'}
# fourtrestwo
# 뭐하나물어볼게
# 뭐하나물어볼게
# 꿈에서도너가둥둥
# 떠다닐것같애맞아
# 멋진남자되고파
# fitness끊은것같애맞아
# 18 15 {'member': 'Vernon', 'lyric': 'Four tres two', 'section': 4, 'line': 0, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Dino', 'lyric': '뭐 하나 물어볼게', 'section': 5, 'line': 0} {'start': '00:54.34', 'end': '00:55.51', 'lyric': '뭐 하나 물어볼게', 'delta': '00:01:17'}
# 뭐하나물어볼게
# 뭐하나물어볼게
# 19 16 {'member': 'Dino', 'lyric': '뭐 하나 물어볼게', 'section': 5, 'line': 0, 'start': '00:54.34', 'end': '00:55.51', 'delta': '00:01:17'}
#
# {'member': 'Dino', 'lyric': '꿈에서도 너가 둥둥', 'section': 5, 'line': 1} {'start': '00:55.51', 'end': '00:57.27', 'lyric': '꿈에서도 너가 둥둥', 'delta': '00:01:76'}
# 꿈에서도너가둥둥
# 꿈에서도너가둥둥
# 20 17 {'member': 'Dino', 'lyric': '꿈에서도 너가 둥둥', 'section': 5, 'line': 1, 'start': '00:55.51', 'end': '00:57.27', 'delta': '00:01:76'}
#
# {'member': 'Dino', 'lyric': '떠다닐 것 같애', 'section': 5, 'line': 2} {'start': '00:57.27', 'end': '00:59.31', 'lyric': '떠 다닐 것 같애 맞아', 'delta': '00:02:04'}
# 떠다닐것같애
# 떠다닐것같애맞아
# 떠다닐것같애
# 맞아
# 22 18 {'member': 'Dino', 'lyric': '떠다닐 것 같애 맞아 ', 'section': 5, 'line': 2, 'start': '00:57.27', 'end': '00:59.31', 'delta': '00:02:04'}
#
# {'member': 'Vernon', 'lyric': '멋진 남자 되고파 Fitness', 'section': 5, 'line': 4} {'start': '00:59.31', 'end': '01:00.72', 'lyric': '멋진 남자 되고파', 'delta': '00:01:41'}
# 멋진남자되고파fitness
# 멋진남자되고파
# 멋진남자되고파
# fitness끊은것같애맞아
# 연애가첨이라
# 내가긴장할것같애
# 너가나의모든의문점에대한
# 23 18 {'member': 'Vernon', 'lyric': '멋진 남자 되고파 Fitness', 'section': 5, 'line': 4, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Vernon', 'lyric': '끊은 것 같애', 'section': 5, 'line': 5} {'start': '00:59.31', 'end': '01:00.72', 'lyric': '멋진 남자 되고파', 'delta': '00:01:41'}
# 끊은것같애
# 멋진남자되고파
# 끊은것같애
# 맞아
# 연애가첨이라내가
# 긴장할것같애
# 너가나의모든의문점에
# 23 19 {'member': 'Vernon', 'lyric': '멋진 남자 되고파', 'section': 5, 'line': 5, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Vernon', 'lyric': '끊은 것 같애', 'section': 5, 'line': 5} {'start': '01:00.72', 'end': '01:03.14', 'lyric': 'Fitness 끊은 것 같애 맞아', 'delta': '00:02:42'}
# 끊은것같애
# fitness끊은것같애맞아
# 끊은것같애
# 맞아
# 연애가첨이라내가
# 긴장할것같애
# 너가나의모든의문점에
# 23 20 {'member': 'Vernon', 'lyric': 'Fitness 끊은 것 같애 맞아', 'section': 5, 'line': 5, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Vernon', 'lyric': '끊은 것 같애', 'section': 5, 'line': 5} {'start': '01:03.14', 'end': '01:04.64', 'lyric': '연애가 첨이라', 'delta': '00:01:50'}
# 끊은것같애
# 연애가첨이라
# 끊은것같애
# 맞아
# 연애가첨이라내가
# 긴장할것같애
# 너가나의모든의문점에
# 23 21 {'member': 'Vernon', 'lyric': '연애가 첨이라', 'section': 5, 'line': 5, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Vernon', 'lyric': '끊은 것 같애', 'section': 5, 'line': 5} {'start': '01:04.64', 'end': '01:06.51', 'lyric': '내가 긴장할 것 같애', 'delta': '00:01:87'}
# 끊은것같애
# 내가긴장할것같애
# 끊은것같애
# 맞아
# 연애가첨이라내가
# 긴장할것같애
# 너가나의모든의문점에
# 23 22 {'member': 'Vernon', 'lyric': '내가 긴장할 것 같애', 'section': 5, 'line': 5, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Vernon', 'lyric': '끊은 것 같애', 'section': 5, 'line': 5} {'start': '01:06.51', 'end': '01:09.05', 'lyric': '너가 나의 모든 의문점에 대한', 'delta': '00:02:54'}
# 끊은것같애
# 너가나의모든의문점에대한
# 끊은것같애
# 맞아
# 연애가첨이라내가
# 긴장할것같애
# 너가나의모든의문점에
# 23 23 {'member': 'Vernon', 'lyric': '너가 나의 모든 의문점에 대한', 'section': 5, 'line': 5, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Vernon', 'lyric': '끊은 것 같애', 'section': 5, 'line': 5} {'start': '01:09.05', 'end': '01:10.48', 'lyric': '정답인 것 같애', 'delta': '00:01:43'}
# 끊은것같애
# 정답인것같애
# 끊은것같애
# 맞아
# 연애가첨이라내가
# 긴장할것같애
# 너가나의모든의문점에
# 23 24 {'member': 'Vernon', 'lyric': '정답인 것 같애', 'section': 5, 'line': 5, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Vernon', 'lyric': '끊은 것 같애', 'section': 5, 'line': 5} {'start': '01:10.48', 'end': '01:12.23', 'lyric': '아 궁금한 게 있는데', 'delta': '00:01:75'}
# 끊은것같애
# 아궁금한게있는데
# 끊은것같애
# 맞아
# 연애가첨이라내가
# 긴장할것같애
# 너가나의모든의문점에
# 23 25 {'member': 'Vernon', 'lyric': '아 궁금한 게 있는데', 'section': 5, 'line': 5, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Vernon', 'lyric': '끊은 것 같애', 'section': 5, 'line': 5} {'start': '01:12.23', 'end': '01:14.46', 'lyric': '어떻게 그리 예뻐', 'delta': '00:02:23'}
# 끊은것같애
# 어떻게그리예뻐
# 끊은것같애
# 맞아
# 연애가첨이라내가
# 긴장할것같애
# 너가나의모든의문점에
# 23 26 {'member': 'Vernon', 'lyric': '어떻게 그리 예뻐', 'section': 5, 'line': 5, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Vernon', 'lyric': '끊은 것 같애', 'section': 5, 'line': 5} {'start': '01:14.46', 'end': '01:16.26', 'lyric': '신호등만 건너면', 'delta': '00:01:80'}
# 끊은것같애
# 신호등만건너면
# 끊은것같애
# 맞아
# 연애가첨이라내가
# 긴장할것같애
# 너가나의모든의문점에
# 23 27 {'member': 'Vernon', 'lyric': '신호등만 건너면', 'section': 5, 'line': 5, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Vernon', 'lyric': '끊은 것 같애', 'section': 5, 'line': 5} {'start': '01:16.26', 'end': '01:18.39', 'lyric': '맛있는 가게 있어', 'delta': '00:02:13'}
# 끊은것같애
# 맛있는가게있어
# 끊은것같애
# 맞아
# 연애가첨이라내가
# 긴장할것같애
# 너가나의모든의문점에
# 23 28 {'member': 'Vernon', 'lyric': '맛있는 가게 있어', 'section': 5, 'line': 5, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Vernon', 'lyric': '끊은 것 같애', 'section': 5, 'line': 5} {'start': '01:18.39', 'end': '01:19.02', 'lyric': '가자', 'delta': '00:00:63'}
# 끊은것같애
# 가자
# 가자
# 오늘날씨너를많이닮아
# 너에게가는길은꽃길이되고
# 보일듯말듯한네마음보인다면
# 온몸이간질간질두근두근
# 24 28 {'member': 'Vernon', 'lyric': '끊은 것 같애', 'section': 5, 'line': 5, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Dino', 'lyric': '맞아', 'section': 5, 'line': 6} {'start': '01:18.39', 'end': '01:19.02', 'lyric': '가자', 'delta': '00:00:63'}
# 맞아
# 가자
# 가자
# 오늘날씨너를많이닮아
# 너에게가는길은꽃길이되고
# 보일듯말듯한네마음보인다면
# 온몸이간질간질두근두근
# 25 28 {'member': 'Dino', 'lyric': '맞아', 'section': 5, 'line': 6, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Dino', 'lyric': '연애가 첨이라 내가', 'section': 5, 'line': 7} {'start': '01:18.39', 'end': '01:19.02', 'lyric': '가자', 'delta': '00:00:63'}
# 연애가첨이라내가
# 가자
# 가자
# 오늘날씨너를많이닮아
# 너에게가는길은꽃길이되고
# 보일듯말듯한네마음보인다면
# 온몸이간질간질두근두근
# 26 28 {'member': 'Dino', 'lyric': '연애가 첨이라 내가', 'section': 5, 'line': 7, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Dino', 'lyric': '긴장할 것 같애', 'section': 5, 'line': 8} {'start': '01:18.39', 'end': '01:19.02', 'lyric': '가자', 'delta': '00:00:63'}
# 긴장할것같애
# 가자
# 가자
# 오늘날씨너를많이닮아
# 너에게가는길은꽃길이되고
# 보일듯말듯한네마음보인다면
# 온몸이간질간질두근두근
# 27 28 {'member': 'Dino', 'lyric': '긴장할 것 같애', 'section': 5, 'line': 8, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Vernon', 'lyric': '너가 나의 모든 의문점에', 'section': 5, 'line': 9} {'start': '01:18.39', 'end': '01:19.02', 'lyric': '가자', 'delta': '00:00:63'}
# 너가나의모든의문점에
# 가자
# 가자
# 오늘날씨너를많이닮아
# 너에게가는길은꽃길이되고
# 보일듯말듯한네마음보인다면
# 온몸이간질간질두근두근
# 28 28 {'member': 'Vernon', 'lyric': '너가 나의 모든 의문점에', 'section': 5, 'line': 9, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Vernon', 'lyric': '대한 정답인 것 같애', 'section': 5, 'line': 10} {'start': '01:18.39', 'end': '01:19.02', 'lyric': '가자', 'delta': '00:00:63'}
# 대한정답인것같애
# 가자
# 가자
# 오늘날씨너를많이닮아
# 너에게가는길은꽃길이되고
# 보일듯말듯한네마음보인다면
# 온몸이간질간질두근두근
# 29 28 {'member': 'Vernon', 'lyric': '대한 정답인 것 같애', 'section': 5, 'line': 10, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'The8', 'lyric': 'Ah 궁금한 게 있는데', 'section': 6, 'line': 0} {'start': '01:18.39', 'end': '01:19.02', 'lyric': '가자', 'delta': '00:00:63'}
# ah궁금한게있는데
# 가자
# 가자
# 오늘날씨너를많이닮아
# 너에게가는길은꽃길이되고
# 보일듯말듯한네마음보인다면
# 온몸이간질간질두근두근
# 30 28 {'member': 'The8', 'lyric': 'Ah 궁금한 게 있는데', 'section': 6, 'line': 0, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'The8', 'lyric': '어떻게 그리 예뻐', 'section': 6, 'line': 1} {'start': '01:18.39', 'end': '01:19.02', 'lyric': '가자', 'delta': '00:00:63'}
# 어떻게그리예뻐
# 가자
# 가자
# 오늘날씨너를많이닮아
# 너에게가는길은꽃길이되고
# 보일듯말듯한네마음보인다면
# 온몸이간질간질두근두근
# 31 28 {'member': 'The8', 'lyric': '어떻게 그리 예뻐', 'section': 6, 'line': 1, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Jun', 'lyric': '신호등만 건너면', 'section': 6, 'line': 2} {'start': '01:18.39', 'end': '01:19.02', 'lyric': '가자', 'delta': '00:00:63'}
# 신호등만건너면
# 가자
# 가자
# 오늘날씨너를많이닮아
# 너에게가는길은꽃길이되고
# 보일듯말듯한네마음보인다면
# 온몸이간질간질두근두근
# 32 28 {'member': 'Jun', 'lyric': '신호등만 건너면', 'section': 6, 'line': 2, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Jun', 'lyric': '맛있는 가게 있어', 'section': 6, 'line': 3} {'start': '01:18.39', 'end': '01:19.02', 'lyric': '가자', 'delta': '00:00:63'}
# 맛있는가게있어
# 가자
# 가자
# 오늘날씨너를많이닮아
# 너에게가는길은꽃길이되고
# 보일듯말듯한네마음보인다면
# 온몸이간질간질두근두근
# 33 28 {'member': 'Jun', 'lyric': '맛있는 가게 있어', 'section': 6, 'line': 3, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Jun', 'lyric': '가자', 'section': 6, 'line': 4} {'start': '01:18.39', 'end': '01:19.02', 'lyric': '가자', 'delta': '00:00:63'}
# 가자
# 가자
# 34 29 {'member': 'Jun', 'lyric': '가자', 'section': 6, 'line': 4, 'start': '01:18.39', 'end': '01:19.02', 'delta': '00:00:63'}
#
# {'member': 'Joshua', 'lyric': '오늘 날씬 너를 많이 닮아', 'section': 7, 'line': 0} {'start': '01:19.02', 'end': '01:22.06', 'lyric': '오늘 날씨 너를 많이 닮아', 'delta': '00:03:04'}
# 오늘날씬너를많이닮아
# 오늘날씨너를많이닮아
# 오늘날씨너를많이닮아
# 너에게가는길은꽃길이되고
# 보일듯말듯한네마음보인다면
# 온몸이간질간질두근두근
# 이기분은뭐야어떡해뭐야어떡해
# 35 29 {'member': 'Joshua', 'lyric': '오늘 날씬 너를 많이 닮아', 'section': 7, 'line': 0, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Joshua', 'lyric': '너에게 가는 길은 꽃길이 되고', 'section': 7, 'line': 1} {'start': '01:19.02', 'end': '01:22.06', 'lyric': '오늘 날씨 너를 많이 닮아', 'delta': '00:03:04'}
# 너에게가는길은꽃길이되고
# 오늘날씨너를많이닮아
# 오늘날씨너를많이닮아
# 너에게가는길은꽃길이되고
# 36 31 {'member': 'Joshua', 'lyric': '', 'section': 7, 'line': 1, 'start': '01:19.02', 'end': '01:22.06', 'delta': '00:03:04'}
#
# {'member': 'DK', 'lyric': '보일 듯 말 듯한 니 맘 보인다면', 'section': 7, 'line': 2} {'start': '01:26.07', 'end': '01:30.15', 'lyric': '보일 듯 말듯한 네 마음 보인다면', 'delta': '00:04:08'}
# 보일듯말듯한니맘보인다면
# 보일듯말듯한네마음보인다면
# 보일듯말듯한니맘보인다면
# 온몸이간질간질두근두근
# 이기분은뭐야어떡해
# 뭐야어떡해
# 아주nice
# 36 32 {'member': 'DK', 'lyric': '보일 듯 말듯한 네 마음 보인다면', 'section': 7, 'line': 2, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'DK', 'lyric': '보일 듯 말 듯한 니 맘 보인다면', 'section': 7, 'line': 2} {'start': '01:30.15', 'end': '01:32.76', 'lyric': '온몸이 간질간질 두근두근', 'delta': '00:02:61'}
# 보일듯말듯한니맘보인다면
# 온몸이간질간질두근두근
# 온몸이간질간질두근두근
# 이기분은뭐야어떡해뭐야어떡해
# 아주nice
# 아주nice
# nice
# 37 32 {'member': 'DK', 'lyric': '보일 듯 말 듯한 니 맘 보인다면', 'section': 7, 'line': 2, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Mingyu', 'lyric': '온몸이 간질간질 두근두근', 'section': 7, 'line': 3} {'start': '01:30.15', 'end': '01:32.76', 'lyric': '온몸이 간질간질 두근두근', 'delta': '00:02:61'}
# 온몸이간질간질두근두근
# 온몸이간질간질두근두근
# 38 33 {'member': 'Mingyu', 'lyric': '온몸이 간질간질 두근두근', 'section': 7, 'line': 3, 'start': '01:30.15', 'end': '01:32.76', 'delta': '00:02:61'}
#
# {'member': 'DK', 'lyric': '이 기분은 뭐야 어떡해', 'section': 7, 'line': 4} {'start': '01:32.76', 'end': '01:38.20', 'lyric': '이 기분은 뭐야 어떡해 뭐야 어떡해', 'delta': '00:05:44'}
# 이기분은뭐야어떡해
# 이기분은뭐야어떡해뭐야어떡해
# 이기분은뭐야어떡해
# 뭐야어떡해
# 40 34 {'member': 'DK', 'lyric': '이 기분은 뭐야 어떡해 뭐야 어떡해 ', 'section': 7, 'line': 4, 'start': '01:32.76', 'end': '01:38.20', 'delta': '00:05:44'}
#
# {'member': 'all', 'lyric': '아주 Nice', 'section': 8, 'line': 0} {'start': '01:38.20', 'end': '01:42.27', 'lyric': '아주 NICE', 'delta': '00:04:07'}
# 아주nice
# 아주nice
# 41 35 {'member': 'all', 'lyric': '아주 Nice', 'section': 8, 'line': 0, 'start': '01:38.20', 'end': '01:42.27', 'delta': '00:04:07'}
#
# {'member': 'all', 'lyric': '아주 Nice', 'section': 8, 'line': 1} {'start': '01:42.27', 'end': '01:46.43', 'lyric': '아주 NICE', 'delta': '00:04:16'}
# 아주nice
# 아주nice
# 42 36 {'member': 'all', 'lyric': '아주 Nice', 'section': 8, 'line': 1, 'start': '01:42.27', 'end': '01:46.43', 'delta': '00:04:16'}
#
# {'member': 'all', 'lyric': '기분 기분 기분', 'section': 8, 'line': 2} {'start': '01:46.43', 'end': '01:50.00', 'lyric': 'NICE', 'delta': '00:03:57'}
# 기분기분기분
# nice
# nice
# 아주nice
# 어떤사람은말하죠
# 연애는연애일뿐이라고
# 그걸로끝이라고
# 43 36 {'member': 'all', 'lyric': '기분 기분 기분', 'section': 8, 'line': 2, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'all', 'lyric': 'Nice', 'section': 8, 'line': 3} {'start': '01:46.43', 'end': '01:50.00', 'lyric': 'NICE', 'delta': '00:03:57'}
# nice
# nice
# 44 37 {'member': 'all', 'lyric': 'Nice', 'section': 8, 'line': 3, 'start': '01:46.43', 'end': '01:50.00', 'delta': '00:03:57'}
#
# {'member': 'all', 'lyric': '아주 Nice', 'section': 8, 'line': 4} {'start': '01:50.00', 'end': '01:52.57', 'lyric': '아주 NICE', 'delta': '00:02:57'}
# 아주nice
# 아주nice
# 45 38 {'member': 'all', 'lyric': '아주 Nice', 'section': 8, 'line': 4, 'start': '01:50.00', 'end': '01:52.57', 'delta': '00:02:57'}
#
# {'member': 'Woozi', 'lyric': '어떤 사람은 말하죠', 'section': 9, 'line': 0} {'start': '01:52.57', 'end': '01:57.35', 'lyric': '어떤 사람은 말하죠', 'delta': '00:04:78'}
# 어떤사람은말하죠
# 어떤사람은말하죠
# 46 39 {'member': 'Woozi', 'lyric': '어떤 사람은 말하죠', 'section': 9, 'line': 0, 'start': '01:52.57', 'end': '01:57.35', 'delta': '00:04:78'}
#
# {'member': 'Woozi', 'lyric': '연애는 연앨 뿐이라고', 'section': 9, 'line': 1} {'start': '01:57.35', 'end': '01:59.92', 'lyric': '연애는 연애일 뿐이라고', 'delta': '00:02:57'}
# 연애는연앨뿐이라고
# 연애는연애일뿐이라고
# 연애는연앨뿐이라고
# 그걸로끝이라고
# 그렇다면시작점이
# 끝이될수있게
# 너로시작해나로끝낼수있게
# 46 40 {'member': 'Woozi', 'lyric': '연애는 연애일 뿐이라고', 'section': 9, 'line': 1, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Woozi', 'lyric': '연애는 연앨 뿐이라고', 'section': 9, 'line': 1} {'start': '01:59.92', 'end': '02:01.80', 'lyric': '그걸로 끝이라고', 'delta': '00:01:88'}
# 연애는연앨뿐이라고
# 그걸로끝이라고
# 그걸로끝이라고
# 그렇다면시작점이끝이될수있게
# 너로시작해나로끝낼수있게
# 맞잡은두손에원처럼
# 우린끝이없네
# 47 40 {'member': 'Woozi', 'lyric': '연애는 연앨 뿐이라고', 'section': 9, 'line': 1, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Woozi', 'lyric': '그걸로 끝이라고', 'section': 9, 'line': 2} {'start': '01:59.92', 'end': '02:01.80', 'lyric': '그걸로 끝이라고', 'delta': '00:01:88'}
# 그걸로끝이라고
# 그걸로끝이라고
# 48 41 {'member': 'Woozi', 'lyric': '그걸로 끝이라고', 'section': 9, 'line': 2, 'start': '01:59.92', 'end': '02:01.80', 'delta': '00:01:88'}
#
# {'member': 'S. Coups', 'lyric': '그렇다면 시작점이', 'section': 10, 'line': 0} {'start': '02:01.80', 'end': '02:04.15', 'lyric': '그렇다면 시작점이 끝이 될 수 있게', 'delta': '00:02:35'}
# 그렇다면시작점이
# 그렇다면시작점이끝이될수있게
# 그렇다면시작점이
# 끝이될수있게
# 50 42 {'member': 'S. Coups', 'lyric': '그렇다면 시작점이 끝이 될 수 있게 ', 'section': 10, 'line': 0, 'start': '02:01.80', 'end': '02:04.15', 'delta': '00:02:35'}
#
# {'member': 'S. Coups', 'lyric': '너로 시작해 나로 끝낼 수 있게', 'section': 10, 'line': 2} {'start': '02:04.15', 'end': '02:06.11', 'lyric': '너로 시작해 나로 끝낼 수 있게', 'delta': '00:01:96'}
# 너로시작해나로끝낼수있게
# 너로시작해나로끝낼수있게
# 51 43 {'member': 'S. Coups', 'lyric': '너로 시작해 나로 끝낼 수 있게', 'section': 10, 'line': 2, 'start': '02:04.15', 'end': '02:06.11', 'delta': '00:01:96'}
#
# {'member': 'S. Coups', 'lyric': '맞잡은 두 손에 원처럼', 'section': 10, 'line': 3} {'start': '02:06.11', 'end': '02:08.07', 'lyric': '맞잡은 두 손에 원처럼', 'delta': '00:01:96'}
# 맞잡은두손에원처럼
# 맞잡은두손에원처럼
# 52 44 {'member': 'S. Coups', 'lyric': '맞잡은 두 손에 원처럼', 'section': 10, 'line': 3, 'start': '02:06.11', 'end': '02:08.07', 'delta': '00:01:96'}
#
# {'member': 'S. Coups', 'lyric': '우린 끝이 없네', 'section': 10, 'line': 4} {'start': '02:08.07', 'end': '02:09.62', 'lyric': '우린 끝이 없네', 'delta': '00:01:55'}
# 우린끝이없네
# 우린끝이없네
# 53 45 {'member': 'S. Coups', 'lyric': '우린 끝이 없네', 'section': 10, 'line': 4, 'start': '02:08.07', 'end': '02:09.62', 'delta': '00:01:55'}
#
# {'member': 'Wonwoo', 'lyric': '맞잡은 두 손에 원처럼', 'section': 10, 'line': 5} {'start': '02:09.62', 'end': '02:11.67', 'lyric': '지금 상황 FOREVER', 'delta': '00:02:05'}
# 맞잡은두손에원처럼
# 지금상황forever
# 맞잡은두손에원처럼
# 우린끝이없네
# 지금상황forever
# 56 46 {'member': 'Wonwoo', 'lyric': '지금 상황 Forever ', 'section': 10, 'line': 5, 'start': '02:09.62', 'end': '02:11.67', 'delta': '00:02:05'}
#
# {'member': 'Jeonghan', 'lyric': '우리 둘이 Forever', 'section': 11, 'line': 1} {'start': '02:11.67', 'end': '02:13.68', 'lyric': '우리 둘이 FOREVER', 'delta': '00:02:01'}
# 우리둘이forever
# 우리둘이forever
# 57 47 {'member': 'Jeonghan', 'lyric': '우리 둘이 Forever', 'section': 11, 'line': 1, 'start': '02:11.67', 'end': '02:13.68', 'delta': '00:02:01'}
#
# {'member': 'Jeonghan', 'lyric': '첫사랑은 안 이뤄진단', 'section': 11, 'line': 2} {'start': '02:13.68', 'end': '02:16.49', 'lyric': '첫사랑은 안 이루어 진단 말은', 'delta': '00:02:81'}
# 첫사랑은안이뤄진단
# 첫사랑은안이루어진단말은
# 첫사랑은안이뤄진단
# 말은믿지않기로해요
# 익숙함에속아
# 잃지않았으면해서로가
# 우리라는말이지켜질수있게
# 57 48 {'member': 'Jeonghan', 'lyric': '첫사랑은 안 이루어 진단 말은', 'section': 11, 'line': 2, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Jeonghan', 'lyric': '첫사랑은 안 이뤄진단', 'section': 11, 'line': 2} {'start': '02:16.49', 'end': '02:18.17', 'lyric': '믿지 않기로 해요', 'delta': '00:01:68'}
# 첫사랑은안이뤄진단
# 믿지않기로해요
# 믿지않기로해요
# 익숙함에속아잃지않았으면해
# 서로가
# 우리라는말이지켜질수있게
# 진지한데뜬금없지만
# 58 48 {'member': 'Jeonghan', 'lyric': '첫사랑은 안 이뤄진단', 'section': 11, 'line': 2, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Jeonghan', 'lyric': '말은 믿지 않기로 해요', 'section': 11, 'line': 3} {'start': '02:16.49', 'end': '02:18.17', 'lyric': '믿지 않기로 해요', 'delta': '00:01:68'}
# 말은믿지않기로해요
# 믿지않기로해요
# 믿지않기로해요
# 익숙함에속아잃지않았으면해
# 서로가
# 우리라는말이지켜질수있게
# 진지한데뜬금없지만
# 59 48 {'member': 'Jeonghan', 'lyric': '말은 믿지 않기로 해요', 'section': 11, 'line': 3, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Mingyu', 'lyric': '익숙함에 속아', 'section': 11, 'line': 4} {'start': '02:16.49', 'end': '02:18.17', 'lyric': '믿지 않기로 해요', 'delta': '00:01:68'}
# 익숙함에속아
# 믿지않기로해요
# 익숙함에속아
# 잃지않았으면해서로가
# 우리라는말이지켜질수있게
# 진지한데뜬금없지만
# 뜬금없지만woa
# 59 49 {'member': 'Mingyu', 'lyric': '믿지 않기로 해요', 'section': 11, 'line': 4, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Mingyu', 'lyric': '익숙함에 속아', 'section': 11, 'line': 4} {'start': '02:18.17', 'end': '02:20.70', 'lyric': '익숙함에 속아 잃지 않았으면 해', 'delta': '00:02:53'}
# 익숙함에속아
# 익숙함에속아잃지않았으면해
# 익숙함에속아
# 잃지않았으면해서로가
# 우리라는말이지켜질수있게
# 진지한데뜬금없지만
# 뜬금없지만woa
# 59 50 {'member': 'Mingyu', 'lyric': '익숙함에 속아 잃지 않았으면 해', 'section': 11, 'line': 4, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Mingyu', 'lyric': '익숙함에 속아', 'section': 11, 'line': 4} {'start': '02:20.70', 'end': '02:21.73', 'lyric': '서로가', 'delta': '00:01:03'}
# 익숙함에속아
# 서로가
# 서로가
# 우리라는말이지켜질수있게
# 진지한데뜬금없지만
# 뜬금없지만오늘난말야
# 아주nice
# 60 50 {'member': 'Mingyu', 'lyric': '익숙함에 속아', 'section': 11, 'line': 4, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Mingyu', 'lyric': '잃지 않았으면 해 서로가', 'section': 11, 'line': 5} {'start': '02:20.70', 'end': '02:21.73', 'lyric': '서로가', 'delta': '00:01:03'}
# 잃지않았으면해서로가
# 서로가
# 서로가
# 우리라는말이지켜질수있게
# 진지한데뜬금없지만
# 뜬금없지만오늘난말야
# 아주nice
# 61 50 {'member': 'Mingyu', 'lyric': '잃지 않았으면 해 서로가', 'section': 11, 'line': 5, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Wonwoo', 'lyric': '우리라는 말이 지켜질 수 있게', 'section': 11, 'line': 6} {'start': '02:20.70', 'end': '02:21.73', 'lyric': '서로가', 'delta': '00:01:03'}
# 우리라는말이지켜질수있게
# 서로가
# 서로가
# 우리라는말이지켜질수있게
# 62 52 {'member': 'Wonwoo', 'lyric': '', 'section': 11, 'line': 6, 'start': '02:20.70', 'end': '02:21.73', 'delta': '00:01:03'}
#
# {'member': 'Seungkwan', 'lyric': '진지한데 뜬금없지만', 'section': 11, 'line': 7} {'start': '02:24.12', 'end': '02:27.61', 'lyric': '진지한데 뜬금없지만', 'delta': '00:03:49'}
# 진지한데뜬금없지만
# 진지한데뜬금없지만
# 63 53 {'member': 'Seungkwan', 'lyric': '진지한데 뜬금없지만', 'section': 11, 'line': 7, 'start': '02:24.12', 'end': '02:27.61', 'delta': '00:03:49'}
#
# {'member': 'DK', 'lyric': '뜬금없지만 Woa', 'section': 11, 'line': 8} {'start': '02:27.61', 'end': '02:33.48', 'lyric': '뜬금없지만 오늘 난 말야', 'delta': '00:05:87'}
# 뜬금없지만woa
# 뜬금없지만오늘난말야
# 뜬금없지만woa
# 오늘난말야
# 아주nice
# 아주nice
# 기분기분기분
# 63 54 {'member': 'DK', 'lyric': '뜬금없지만 오늘 난 말야', 'section': 11, 'line': 8, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'DK', 'lyric': '뜬금없지만 Woa', 'section': 11, 'line': 8} {'start': '02:33.48', 'end': '02:37.30', 'lyric': '아주 NICE', 'delta': '00:03:82'}
# 뜬금없지만woa
# 아주nice
# 아주nice
# 아주nice
# nice
# 아주nice
# 오늘하루도아주즐거웠어요
# 64 54 {'member': 'DK', 'lyric': '뜬금없지만 Woa', 'section': 11, 'line': 8, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'Seungkwan', 'lyric': '오늘 난 말야', 'section': 11, 'line': 9} {'start': '02:33.48', 'end': '02:37.30', 'lyric': '아주 NICE', 'delta': '00:03:82'}
# 오늘난말야
# 아주nice
# 오늘난말야
# 아주nice
# 66 55 {'member': 'Seungkwan', 'lyric': '아주 Nice ', 'section': 11, 'line': 9, 'start': '02:33.48', 'end': '02:37.30', 'delta': '00:03:82'}
#
# {'member': 'all', 'lyric': '아주 Nice', 'section': 12, 'line': 1} {'start': '02:37.30', 'end': '02:41.55', 'lyric': '아주 NICE', 'delta': '00:04:25'}
# 아주nice
# 아주nice
# 67 56 {'member': 'all', 'lyric': '아주 Nice', 'section': 12, 'line': 1, 'start': '02:37.30', 'end': '02:41.55', 'delta': '00:04:25'}
#
# {'member': 'all', 'lyric': '기분 기분 기분', 'section': 12, 'line': 2} {'start': '02:41.55', 'end': '02:45.15', 'lyric': 'NICE', 'delta': '00:03:60'}
# 기분기분기분
# nice
# nice
# 아주nice
# 오늘하루도아주즐거웠어요
# 다음데이트도빨리했음좋겠어요
# 집데려다주는길이너무도짧아요
# 68 56 {'member': 'all', 'lyric': '기분 기분 기분', 'section': 12, 'line': 2, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}
#
# {'member': 'all', 'lyric': 'Nice', 'section': 12, 'line': 3} {'start': '02:41.55', 'end': '02:45.15', 'lyric': 'NICE', 'delta': '00:03:60'}
# nice
# nice
# 69 57 {'member': 'all', 'lyric': 'Nice', 'section': 12, 'line': 3, 'start': '02:41.55', 'end': '02:45.15', 'delta': '00:03:60'}
#
# {'member': 'all', 'lyric': '아주 Nice', 'section': 12, 'line': 4} {'start': '02:45.15', 'end': '02:49.45', 'lyric': '아주 NICE', 'delta': '00:04:30'}
# 아주nice
# 아주nice
# 70 58 {'member': 'all', 'lyric': '아주 Nice', 'section': 12, 'line': 4, 'start': '02:45.15', 'end': '02:49.45', 'delta': '00:04:30'}
#
# {'member': 'all', 'lyric': '오늘 하루도 아주 즐거웠어요', 'section': 13, 'line': 0} {'start': '02:49.45', 'end': '02:53.25', 'lyric': '오늘 하루도 아주 즐거웠어요', 'delta': '00:03:80'}
# 오늘하루도아주즐거웠어요
# 오늘하루도아주즐거웠어요
# 71 59 {'member': 'all', 'lyric': '오늘 하루도 아주 즐거웠어요', 'section': 13, 'line': 0, 'start': '02:49.45', 'end': '02:53.25', 'delta': '00:03:80'}
#
# {'member': 'all', 'lyric': '다음 데이트도 빨리 했음 좋겠어요', 'section': 13, 'line': 1} {'start': '02:53.25', 'end': '02:57.18', 'lyric': '다음 데이트도 빨리 했음 좋겠어요', 'delta': '00:03:93'}
# 다음데이트도빨리했음좋겠어요
# 다음데이트도빨리했음좋겠어요
# 72 60 {'member': 'all', 'lyric': '다음 데이트도 빨리 했음 좋겠어요', 'section': 13, 'line': 1, 'start': '02:53.25', 'end': '02:57.18', 'delta': '00:03:93'}
#
# {'member': 'all', 'lyric': '집 데려다 주는 길이 너무도 짧아요', 'section': 13, 'line': 2} {'start': '02:57.18', 'end': '03:01.02', 'lyric': '집 데려다 주는 길이 너무도 짧아요', 'delta': '00:03:84'}
# 집데려다주는길이너무도짧아요
# 집데려다주는길이너무도짧아요
# 73 61 {'member': 'all', 'lyric': '집 데려다 주는 길이 너무도 짧아요', 'section': 13, 'line': 2, 'start': '02:57.18', 'end': '03:01.02', 'delta': '00:03:84'}
#
# {'member': 'all', 'lyric': '내일 이 시간에 또 만나요', 'section': 13, 'line': 3} {'start': '03:01.02', 'end': '03:04.28', 'lyric': '내일 이 시간에 또 만나요', 'delta': '00:03:26'}
# 내일이시간에또만나요
# 내일이시간에또만나요
# 74 62 {'member': 'all', 'lyric': '내일 이 시간에 또 만나요', 'section': 13, 'line': 3, 'start': '03:01.02', 'end': '03:04.28', 'delta': '00:03:26'}
#
# [{'member': 'Vernon', 'lyric': 'Four tres two uno uno two', 'section': 0, 'line': 0, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}, {'member': 'DK', 'lyric': '아침엔 모닝콜 필수던 내가', 'section': 1, 'line': 0, 'start': '00:03.37', 'end': '00:07.22', 'delta': '00:03:85'}, {'member': 'DK', 'lyric': '오늘은 번쩍 번쩍 눈이 떠지는가', 'section': 1, 'line': 1, 'start': '00:07.22', 'end': '00:11.29', 'delta': '00:04:07'}, {'member': 'Hoshi', 'lyric': '데이트 날이라 그런지', 'section': 1, 'line': 2, 'start': '00:11.29', 'end': '00:13.63', 'delta': '00:02:34'}, {'member': 'Hoshi', 'lyric': '어제 꿈도 좋은 꿈 꿨지', 'section': 1, 'line': 3, 'start': '00:13.63', 'end': '00:15.72', 'delta': '00:02:09'}, {'member': 'Wonwoo', 'lyric': '새 신발을 신고', 'section': 1, 'line': 4, 'start': '00:15.72', 'end': '00:17.77', 'delta': '00:02:05'}, {'member': 'Mingyu', 'lyric': '현관문을 열고 나가면', 'section': 1, 'line': 5, 'start': '00:17.77', 'end': '00:19.79', 'delta': '00:02:02'}, {'member': 'Seungkwan', 'lyric': '오늘 날씬 너를 많이 닮아', 'section': 2, 'line': 0, 'start': '00:19.79', 'end': '00:22.90', 'delta': '00:03:11'}, {'member': 'Seungkwan', 'lyric': '너에게 가는 길은 꽃길이 되고', 'section': 2, 'line': 1, 'start': '00:22.90', 'end': '00:26.81', 'delta': '00:03:91'}, {'member': 'DK', 'lyric': '보일 듯 말듯한 네 마음 보인다면', 'section': 2, 'line': 2, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}, {'member': 'DK', 'lyric': '보일 듯 말 듯한 니 맘 보인다면', 'section': 2, 'line': 2, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}, {'member': 'Mingyu', 'lyric': '온몸이 간질간질 두근두근', 'section': 2, 'line': 3, 'start': '00:30.92', 'end': '00:33.52', 'delta': '00:02:60'}, {'member': 'Joshua', 'lyric': '이 기분은 뭐야 어떡해', 'section': 2, 'line': 4, 'start': '00:33.52', 'end': '00:37.00', 'delta': '00:03:48'}, {'member': 'all', 'lyric': '아주 Nice', 'section': 3, 'line': 0, 'start': '00:37.00', 'end': '00:40.99', 'delta': '00:03:99'}, {'member': 'all', 'lyric': '아주 Nice', 'section': 3, 'line': 1, 'start': '00:40.99', 'end': '00:45.26', 'delta': '00:04:27'}, {'member': 'all', 'lyric': '기분 기분 기분', 'section': 3, 'line': 2, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}, {'member': 'all', 'lyric': 'Nice', 'section': 3, 'line': 3, 'start': '00:45.26', 'end': '00:48.86', 'delta': '00:03:60'}, {'member': 'all', 'lyric': '아주 Nice', 'section': 3, 'line': 4, 'start': '00:48.86', 'end': '00:52.32', 'delta': '00:03:46'}, {'member': 'Vernon', 'lyric': 'Four tres two', 'section': 4, 'line': 0, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}, {'member': 'Dino', 'lyric': '뭐 하나 물어볼게', 'section': 5, 'line': 0, 'start': '00:54.34', 'end': '00:55.51', 'delta': '00:01:17'}, {'member': 'Dino', 'lyric': '꿈에서도 너가 둥둥', 'section': 5, 'line': 1, 'start': '00:55.51', 'end': '00:57.27', 'delta': '00:01:76'}, {'member': 'Dino', 'lyric': '떠다닐 것 같애 맞아 ', 'section': 5, 'line': 2, 'start': '00:57.27', 'end': '00:59.31', 'delta': '00:02:04'}, {'member': 'Vernon', 'lyric': '멋진 남자 되고파 Fitness', 'section': 5, 'line': 4, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}, {'member': 'Vernon', 'lyric': '멋진 남자 되고파', 'section': 5, 'line': 5, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}, {'member': 'Vernon', 'lyric': 'Fitness 끊은 것 같애 맞아', 'section': 5, 'line': 5, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}, {'member': 'Vernon', 'lyric': '연애가 첨이라', 'section': 5, 'line': 5, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}, {'member': 'Vernon', 'lyric': '내가 긴장할 것 같애', 'section': 5, 'line': 5, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}, {'member': 'Vernon', 'lyric': '너가 나의 모든 의문점에 대한', 'section': 5, 'line': 5, 'start': 'LINE NOT SYNCED', 'end': 'LINE NOT SYNCED', 'delta': 'LINE NOT SYNCED'}, {'member': 'Vernon', 'lyric': '정답인 것 같애', 'section': 5, 'line': 5, ' ...

# %%
meta_info['synced_lyrics'] = synced_and_assigned_lyrics

del meta_info["plainLyrics"]
del meta_info["syncedLyrics"]

print(meta_info)
# Out:
# {'id': 2433441, 'name': 'Rock with you', 'trackName': 'Rock with you', 'artistName': 'SEVENTEEN', 'albumName': "SEVENTEEN 9th Mini Album 'Attacca'", 'duration': 180.0, 'instrumental': False, 'synced_lyrics': [{'member': 'Joshua', 'lyric': '지금 이 노래가 내가 될 수 있게', 'section': 0, 'line': 0, 'start': '00:00:00', 'end': '00:06:33', 'delta': '00:06:33'}, {'member': 'Joshua', 'lyric': '만들어 준 네가 다가온다', 'section': 0, 'line': 1, 'start': '00:06:33', 'end': '00:10:01', 'delta': '00:03:68'}, {'member': 'Joshua', 'lyric': '셋 둘 하나', 'section': 0, 'line': 2, 'start': '00:10:01', 'end': '00:11:38', 'delta': '00:01:37'}, {'member': 'Jeonghan', 'lyric': '뭐든지 다 주고 싶어', 'section': 1, 'line': 0, 'start': '00:11:38', 'end': '00:14:38', 'delta': '00:03:00'}, {'member': 'Jeonghan', 'lyric': '나에게 너만 있다면', 'section': 1, 'line': 1, 'start': '00:14:38', 'end': '00:16:93', 'delta': '00:02:55'}, {'member': 'Hoshi', 'lyric': 'Won’t let them break your heart oh no', 'section': 1, 'line': 2, 'start': '00:16:93', 'end': '00:20:22', 'delta': '00:03:29'}, {'member': 'Wonwoo', 'lyric': '네가 없다면 난 아무것도 아냐', 'section': 1, 'line': 3, 'start': '00:20:22', 'end': '00:23:52', 'delta': '00:03:30'}, {'member': 'Mingyu', 'lyric': 'No words are enough for you', 'section': 2, 'line': 0, 'start': '00:23:52', 'end': '00:26:31', 'delta': '00:02:79'}, {'member': 'Mingyu', 'lyric': '노랫말로 담고 싶어', 'section': 2, 'line': 1, 'start': '00:26:31', 'end': '00:29:11', 'delta': '00:02:80'}, {'member': 'S.Coups', 'lyric': 'So, 모든 나의 감정  너로 읽고 쓰게 해줘 ', 'section': 2, 'line': 2, 'start': '00:29:11', 'end': '00:34:24', 'delta': '00:05:13'}, {'member': 'DK', 'lyric': 'I just want to love you', 'section': 3, 'line': 0, 'start': '00:34:24', 'end': '00:36:61', 'delta': '00:02:37'}, {'member': 'DK', 'lyric': '널 혼자 두지 않아 난', 'section': 3, 'line': 1, 'start': '00:36:61', 'end': '00:40:08', 'delta': '00:03:47'}, {'member': 'THE8', 'lyric': 'I just want you, I need you', 'section': 3, 'line': 2, 'start': '00:40:08', 'end': '00:42:83', 'delta': '00:02:75'}, {'member': 'THE8', 'lyric': '이 밤은 짧고 넌 당연하지 않아', 'section': 3, 'line': 3, 'start': '00:42:83', 'end': '00:46:50', 'delta': '00:03:67'}, {'member': 'Seungkwan', 'lyric': 'I tell you', 'section': 4, 'line': 0, 'start': '00:46:50', 'end': '00:47:33', 'delta': '00:00:83'}, {'member': 'Seungkwan', 'lyric': 'This time I wanna rock with you', 'section': 4, 'line': 1, 'start': '00:47:33', 'end': '00:50:46', 'delta': '00:03:13'}, {'member': 'Seungkwan', 'lyric': 'Moonlight 이 밤에 Shine on you', 'section': 4, 'line': 2, 'start': '00:50:46', 'end': '00:53:21', 'delta': '00:02:75'}, {'member': 'Jun', 'lyric': 'Tonight I wanna ride with you', 'section': 4, 'line': 3, 'start': '00:53:21', 'end': '00:57:55', 'delta': '00:04:34'}, {'member': 'Jun', 'lyric': '그 어디라도', 'section': 4, 'line': 4, 'start': '00:57:55', 'end': '00:58:93', 'delta': '00:01:38'}, {'member': 'Vernon', 'lyric': 'Baby hold on Baby hold on', 'section': 5, 'line': 0, 'start': '00:58:93', 'end': '01:00:18', 'delta': '00:01:25'}, {'member': 'Dino', 'lyric': '어디에서도', 'section': 5, 'line': 1, 'start': '01:00:18', 'end': '01:01:77', 'delta': '00:01:59'}, {'member': 'Vernon', 'lyric': 'Baby hold on Baby hold on', 'section': 5, 'line': 2, 'start': '01:01:77', 'end': '01:03:52', 'delta': '00:01:75'}, {'member': 'Dino', 'lyric': '어디서라도', 'section': 5, 'line': 3, 'start': '01:03:52', 'end': '01:05:02', 'delta': '00:01:50'}, {'member': 'Vernon', 'lyric': '세상이 끝나더라도', 'section': 5, 'line': 4, 'start': '01:05:02', 'end': '01:09:11', 'delta': '00:04:09'}, {'member': 'Dino', 'lyric': 'I wanna ride with you', 'section': 5, 'line': 5, 'start': '01:09:11', 'end': '01:11:23', 'delta': '00:02:12'}, {'member': 'Wonwoo', 'lyric': '널 위해 달리고 있어', 'section': 6, 'line': 0, 'start': '01:12:19', 'end': '01:14:94', 'delta': '00:02:75'}, {'member': 'Wonwoo', 'lyric': '널 위해서라면 뭐든', 'section': 6, 'line': 1, 'start': '01:14:94', 'end': '01:18:03', 'delta': '00:03:09'}, {'member': 'Jun', 'lyric': '숨이 멈출 때까지 난 너만', 'section': 6, 'line': 2 ...

# %%
with open('./data/meta_info_'+song+'.json', 'w', encoding='utf-8') as f:
    json.dump(meta_info, f, ensure_ascii=False)

# %%
# Out:
# [<span style="color: #63b76c">Four tres two uno uno two</span>]
# <span style="color: #3d72e7">아침엔 모닝콜 필수던 내가
# 오늘은 번쩍 번쩍 눈이 떠지는가</span>
# lines ['아침엔 모닝콜 필수던 내가', '오늘은 번쩍 번쩍 눈이 떠지는가']
# new_spans ['<span style="color: #3d72e7">아침엔 모닝콜 필수던 내가</span>', '<span style="color: #3d72e7">오늘은 번쩍 번쩍 눈이 떠지는가</span>']
# <span style="color: #c04737">데이트 날이라 그런지
# 어제 꿈도 좋은 꿈 꿨지</span>
# lines ['데이트 날이라 그런지', '어제 꿈도 좋은 꿈 꿨지']
# new_spans ['<span style="color: #3d72e7">아침엔 모닝콜 필수던 내가</span>', '<span style="color: #3d72e7">오늘은 번쩍 번쩍 눈이 떠지는가</span>', '<span style="color: #c04737">데이트 날이라 그런지</span>', '<span style="color: #c04737">어제 꿈도 좋은 꿈 꿨지</span>']
# <span style="color: #855fc4">새 신발을 신고</span>
# lines ['새 신발을 신고']
# new_spans ['<span style="color: #3d72e7">아침엔 모닝콜 필수던 내가</span>', '<span style="color: #3d72e7">오늘은 번쩍 번쩍 눈이 떠지는가</span>', '<span style="color: #c04737">데이트 날이라 그런지</span>', '<span style="color: #c04737">어제 꿈도 좋은 꿈 꿨지</span>', '<span style="color: #855fc4">새 신발을 신고</span>']
# <span style="color: #04a497">현관문을 열고 나가면</span>
# lines ['현관문을 열고 나가면']
# new_spans ['<span style="color: #3d72e7">아침엔 모닝콜 필수던 내가</span>', '<span style="color: #3d72e7">오늘은 번쩍 번쩍 눈이 떠지는가</span>', '<span style="color: #c04737">데이트 날이라 그런지</span>', '<span style="color: #c04737">어제 꿈도 좋은 꿈 꿨지</span>', '<span style="color: #855fc4">새 신발을 신고</span>', '<span style="color: #04a497">현관문을 열고 나가면</span>']
# <span style="color: #f1ce5f">오늘 날씬 너를 많이 닮아
# 너에게 가는 길은 꽃길이 되고</span>
# lines ['오늘 날씬 너를 많이 닮아', '너에게 가는 길은 꽃길이 되고']
# new_spans ['<span style="color: #f1ce5f">오늘 날씬 너를 많이 닮아</span>', '<span style="color: #f1ce5f">너에게 가는 길은 꽃길이 되고</span>']
# <span style="color: #3d72e7">보일 듯 말 듯한 니 맘 보인다면</span>
# lines ['보일 듯 말 듯한 니 맘 보인다면']
# new_spans ['<span style="color: #f1ce5f">오늘 날씬 너를 많이 닮아</span>', '<span style="color: #f1ce5f">너에게 가는 길은 꽃길이 되고</span>', '<span style="color: #3d72e7">보일 듯 말 듯한 니 맘 보인다면</span>']
# <span style="color: #04a497">온몸이 간질간질 두근두근</span>
# lines ['온몸이 간질간질 두근두근']
# new_spans ['<span style="color: #f1ce5f">오늘 날씬 너를 많이 닮아</span>', '<span style="color: #f1ce5f">너에게 가는 길은 꽃길이 되고</span>', '<span style="color: #3d72e7">보일 듯 말 듯한 니 맘 보인다면</span>', '<span style="color: #04a497">온몸이 간질간질 두근두근</span>']
# <span style="color: #df73ff">이 기분은 뭐야 어떡해</span>
# lines ['이 기분은 뭐야 어떡해']
# new_spans ['<span style="color: #f1ce5f">오늘 날씬 너를 많이 닮아</span>', '<span style="color: #f1ce5f">너에게 가는 길은 꽃길이 되고</span>', '<span style="color: #3d72e7">보일 듯 말 듯한 니 맘 보인다면</span>', '<span style="color: #04a497">온몸이 간질간질 두근두근</span>', '<span style="color: #df73ff">이 기분은 뭐야 어떡해</span>']
# <span style="color: #ffffff">아주 Nice
# 아주 Nice
# 기분 기분 기분
# Nice
# 아주 Nice</span>
# lines ['아주 Nice', '아주 Nice', '기분 기분 기분', 'Nice', '아주 Nice']
# new_spans ['<span style="color: #ffffff">아주 Nice</span>', '<span style="color: #ffffff">아주 Nice</span>', '<span style="color: #ffffff">기분 기분 기분</span>', '<span style="color: #ffffff">Nice</span>', '<span style="color: #ffffff">아주 Nice</span>']
# <span style="color: #63b76c">Four tres two</span>
# lines ['Four tres two']
# new_spans ['<span style="color: #63b76c">Four tres two</span>']
# <span style="color: #d962b6">뭐 하나 물어볼게
# 꿈에서도 너가 둥둥
# 떠다닐 것 같애?</span>
# lines ['뭐 하나 물어볼게', '꿈에서도 너가 둥둥', '떠다닐 것 같애?']
# new_spans ['<span style="color: #d962b6">뭐 하나 물어볼게</span>', '<span style="color: #d962b6">꿈에서도 너가 둥둥</span>', '<span style="color: #d962b6">떠다닐 것 같애?</span>']
# <span style="color: #63b76c">맞아</span>
# lines ['맞아']
# new_spans ['<span style="color: #d962b6">뭐 하나 물어볼게</span>', '<span style="color: #d962b6">꿈에서도 너가 둥둥</span>', '<span style="color: #d962b6">떠다닐 것 같애?</span>', '<span style="color: #63b76c">맞아</span>']
# <span style="color: #63b76c">멋진 남자 되고파 Fitness
# 끊은 것 같애?</span>
# lines ['멋진 남자 되고파 Fitness', '끊은 것 같애?']
# new_spans ['<span style="color: #d962b6">뭐 하나 물어볼게</span>', '<span style="color: #d962b6">꿈에서도 너가 둥둥</span>', '<span style="color: #d962b6">떠다닐 것 같애?</span>', '<span style="color: #63b76c">맞아</span>', '<span style="color: #63b76c">멋진 남자 되고파 Fitness</span>', '<span style="color: #63b76c">끊은 것 같애?</span>']
# <span style="color: #d962b6">맞아</span>
# lines ['맞아']
# new_spans ['<span style="color: #d962b6">뭐 하나 물어볼게</span>', '<span style="color: #d962b6">꿈에서도 너가 둥둥</span>', '<span style="color: #d962b6">떠다닐 것 같애?</span>', '<span style="color: #63b76c">맞아</span>', '<span style="color: #63b76c">멋진 남자 되고파 Fitness</span>', '<span style="color: #63b76c">끊은 것 같애?</span>', '<span style="color: #d962b6">맞아</span>']
# <span style="color: #d962b6">연애가 첨이라 내가
# 긴장할 것 같애?</span>
# lines ['연애가 첨이라 내가', '긴장할 것 같애?']
# new_spans ['<span style="color: #d962b6">뭐 하나 물어볼게</span>', '<span style="color: #d962b6">꿈에서도 너가 둥둥</span>', '<span style="color: #d962b6">떠다닐 것 같애?</span>', '<span style="color: #63b76c">맞아</span>', '<span style="color: #63b76c">멋진 남자 되고파 Fitness</span>', '<span style="color: #63b76c">끊은 것 같애?</span>', '<span style="color: #d962b6">맞아</span>', '<span style="color: #d962b6">연애가 첨이라 내가</span>', '<span style="color: #d962b6">긴장할 것 같애?</span>']
# <span style="color: #63b76c">너가 나의 모든 의문점에
# 대한 정답인 것 같애</span>
# lines ['너가 나의 모든 의문점에', '대한 정답인 것 같애']
# new_spans ['<span style="color: #d962b6">뭐 하나 물어볼게</span>', '<span style="color: #d962b6">꿈에서도 너가 둥둥</span>', '<span style="color: #d962b6">떠다닐 것 같애?</span>', '<span style="color: #63b76c">맞아</span>', '<span style="color: #63b76c">멋진 남자 되고파 Fitness</span>', '<span style="color: #63b76c">끊은 것 같애?</span>', '<span style="color: #d962b6">맞아</span>', '<span style="color: #d962b6">연애가 첨이라 내가</span>', '<span style="color: #d962b6">긴장할 것 같애?</span>', '<span style="color: #63b76c">너가 나의 모든 의문점에</span>', '<span style="color: #63b76c">대한 정답인 것 같애</span>']
# <span style="color: #a1dad7">Ah 궁금한 게 있는데
# 어떻게 그리 예뻐</span>
# lines ['Ah 궁금한 게 있는데', '어떻게 그리 예뻐']
# new_spans ['<span style="color: #a1dad7">Ah 궁금한 게 있는데</span>', '<span style="color: #a1dad7">어떻게 그리 예뻐</span>']
# <span style="color: #bede0d">신호등만 건너면
# 맛있는 가게 있어</span>
# lines ['신호등만 건너면', '맛있는 가게 있어']
# new_spans ['<span style="color: #a1dad7">Ah 궁금한 게 있는데</span>', '<span style="color: #a1dad7">어떻게 그리 예뻐</span>', '<span style="color: #bede0d">신호등만 건너면</span>', '<span style="color: #bede0d">맛있는 가게 있어</span>']
# <span style="color: #bede0d">가자</span>
# lines ['가자']
# new_spans ['<span style="color: #a1dad7">Ah 궁금한 게 있는데</span>', '<span style="color: #a1dad7">어떻게 그리 예뻐</span>', '<span style="color: #bede0d">신호등만 건너면</span>', '<span style="color: #bede0d">맛있는 가게 있어</span>', '<span style="color: #bede0d">가자</span>']
# <span style="color: #df73ff">오늘 날씬 너를 많이 닮아
# 너에게 가는 길은 꽃길이 되고</span>
# lines ['오늘 날씬 너를 많이 닮아', '너에게 가는 길은 꽃길이 되고']
# new_spans ['<span style="color: #df73ff">오늘 날씬 너를 많이 닮아</span>', '<span style="color: #df73ff">너에게 가는 길은 꽃길이 되고</span>']
# <span style="color: #3d72e7">보일 듯 말 듯한 니 맘 보인다면</span>
# lines ['보일 듯 말 듯한 니 맘 보인다면']
# new_spans ['<span style="color: #df73ff">오늘 날씬 너를 많이 닮아</span>', '<span style="color: #df73ff">너에게 가는 길은 꽃길이 되고</span>', '<span style="color: #3d72e7">보일 듯 말 듯한 니 맘 보인다면</span>']
# <span style="color: #04a497">온몸이 간질간질 두근두근</span>
# lines ['온몸이 간질간질 두근두근']
# new_spans ['<span style="color: #df73ff">오늘 날씬 너를 많이 닮아</span>', '<span style="color: #df73ff">너에게 가는 길은 꽃길이 되고</span>', '<span style="color: #3d72e7">보일 듯 말 듯한 니 맘 보인다면</span>', '<span style="color: #04a497">온몸이 간질간질 두근두근</span>']
# <span style="color: #3d72e7">이 기분은 뭐야 어떡해</span>
# lines ['이 기분은 뭐야 어떡해']
# new_spans ['<span style="color: #df73ff">오늘 날씬 너를 많이 닮아</span>', '<span style="color: #df73ff">너에게 가는 길은 꽃길이 되고</span>', '<span style="color: #3d72e7">보일 듯 말 듯한 니 맘 보인다면</span>', '<span style="color: #04a497">온몸이 간질간질 두근두근</span>', '<span style="color: #3d72e7">이 기분은 뭐야 어떡해</span>']
# <span style="color: #3d72e7">뭐야 어떡해</span>
# lines ['뭐야 어떡해']
# new_spans ['<span style="color: #df73ff">오늘 날씬 너를 많이 닮아</span>', '<span style="color: #df73ff">너에게 가는 길은 꽃길이 되고</span>', '<span style="color: #3d72e7">보일 듯 말 듯한 니 맘 보인다면</span>', '<span style="color: #04a497">온몸이 간질간질 두근두근</span>', '<span style="color: #3d72e7">이 기분은 뭐야 어떡해</span>', '<span style="color: #3d72e7">뭐야 어떡해</span>']
# <span style="color: #ffffff">아주 Nice
# 아주 Nice
# 기분 기분 기분
# Nice
# 아주 Nice</span>
# lines ['아주 Nice', '아주 Nice', '기분 기분 기분', 'Nice', '아주 Nice']
# new_spans ['<span style="color: #ffffff">아주 Nice</span>', '<span style="color: #ffffff">아주 Nice</span>', '<span style="color: #ffffff">기분 기분 기분</span>', '<span style="color: #ffffff">Nice</span>', '<span style="color: #ffffff">아주 Nice</span>']
# <span style="color: #ff7d07">어떤 사람은 말하죠
# 연애는 연앨 뿐이라고
# 그걸로 끝이라고</span>
# lines ['어떤 사람은 말하죠', '연애는 연앨 뿐이라고', '그걸로 끝이라고']
# new_spans ['<span style="color: #ff7d07">어떤 사람은 말하죠</span>', '<span style="color: #ff7d07">연애는 연앨 뿐이라고</span>', '<span style="color: #ff7d07">그걸로 끝이라고</span>']
# <span style="color: #4ea8d4">그렇다면 시작점이
# 끝이 될 수 있게
# 너로 시작해 나로 끝낼 수 있게
# <span style="color: #855fc4">맞잡은 두 손에 원처럼</span>
# (<span style="color: #855fc4">우린 끝이 없네</span>)</span>
# lines ['그렇다면 시작점이', '끝이 될 수 있게', '너로 시작해 나로 끝낼 수 있게', '맞잡은 두 손에 원처럼', '(', '우린 끝이 없네', ')']
# new_spans ['<span style="color: #4ea8d4">그렇다면 시작점이</span>', '<span style="color: #4ea8d4">끝이 될 수 있게</span>', '<span style="color: #4ea8d4">너로 시작해 나로 끝낼 수 있게</span>', '<span style="color: #4ea8d4">맞잡은 두 손에 원처럼</span>', '<span style="color: #4ea8d4">(</span>', '<span style="color: #4ea8d4">우린 끝이 없네</span>', '<span style="color: #4ea8d4">)</span>']
# <span style="color: #855fc4">맞잡은 두 손에 원처럼</span>
# lines ['맞잡은 두 손에 원처럼']
# new_spans ['<span style="color: #4ea8d4">그렇다면 시작점이</span>', '<span style="color: #4ea8d4">끝이 될 수 있게</span>', '<span style="color: #4ea8d4">너로 시작해 나로 끝낼 수 있게</span>', '<span style="color: #4ea8d4">맞잡은 두 손에 원처럼</span>', '<span style="color: #4ea8d4">(</span>', '<span style="color: #4ea8d4">우린 끝이 없네</span>', '<span style="color: #4ea8d4">)</span>', '<span style="color: #855fc4">맞잡은 두 손에 원처럼</span>']
# <span style="color: #855fc4">우린 끝이 없네</span>
# lines ['우린 끝이 없네']
# new_spans ['<span style="color: #4ea8d4">그렇다면 시작점이</span>', '<span style="color: #4ea8d4">끝이 될 수 있게</span>', '<span style="color: #4ea8d4">너로 시작해 나로 끝낼 수 있게</span>', '<span style="color: #4ea8d4">맞잡은 두 손에 원처럼</span>', '<span style="color: #4ea8d4">(</span>', '<span style="color: #4ea8d4">우린 끝이 없네</span>', '<span style="color: #4ea8d4">)</span>', '<span style="color: #855fc4">맞잡은 두 손에 원처럼</span>', '<span style="color: #855fc4">우린 끝이 없네</span>']
# <span style="color: #e32636">지금 상황 Forever
# 우리 둘이 Forever
# 첫사랑은 안 이뤄진단
# 말은 믿지 않기로 해요</span>
# lines ['지금 상황 Forever', '우리 둘이 Forever', '첫사랑은 안 이뤄진단', '말은 믿지 않기로 해요']
# new_spans ['<span style="color: #e32636">지금 상황 Forever</span>', '<span style="color: #e32636">우리 둘이 Forever</span>', '<span style="color: #e32636">첫사랑은 안 이뤄진단</span>', '<span style="color: #e32636">말은 믿지 않기로 해요</span>']
# <span style="color: #04a497">익숙함에 속아
# 잃지 않았으면 해 서로가</span>
# lines ['익숙함에 속아', '잃지 않았으면 해 서로가']
# new_spans ['<span style="color: #e32636">지금 상황 Forever</span>', '<span style="color: #e32636">우리 둘이 Forever</span>', '<span style="color: #e32636">첫사랑은 안 이뤄진단</span>', '<span style="color: #e32636">말은 믿지 않기로 해요</span>', '<span style="color: #04a497">익숙함에 속아</span>', '<span style="color: #04a497">잃지 않았으면 해 서로가</span>']
# <span style="color: #855fc4">우리라는 말이 지켜질 수 있게</span>
# lines ['우리라는 말이 지켜질 수 있게']
# new_spans ['<span style="color: #e32636">지금 상황 Forever</span>', '<span style="color: #e32636">우리 둘이 Forever</span>', '<span style="color: #e32636">첫사랑은 안 이뤄진단</span>', '<span style="color: #e32636">말은 믿지 않기로 해요</span>', '<span style="color: #04a497">익숙함에 속아</span>', '<span style="color: #04a497">잃지 않았으면 해 서로가</span>', '<span style="color: #855fc4">우리라는 말이 지켜질 수 있게</span>']
# <span style="color: #f1ce5f">진지한데 뜬금없지만</span>
# lines ['진지한데 뜬금없지만']
# new_spans ['<span style="color: #e32636">지금 상황 Forever</span>', '<span style="color: #e32636">우리 둘이 Forever</span>', '<span style="color: #e32636">첫사랑은 안 이뤄진단</span>', '<span style="color: #e32636">말은 믿지 않기로 해요</span>', '<span style="color: #04a497">익숙함에 속아</span>', '<span style="color: #04a497">잃지 않았으면 해 서로가</span>', '<span style="color: #855fc4">우리라는 말이 지켜질 수 있게</span>', '<span style="color: #f1ce5f">진지한데 뜬금없지만</span>']
# <span style="color: #3d72e7">뜬금없지만 Woa</span>
# lines ['뜬금없지만 Woa']
# new_spans ['<span style="color: #e32636">지금 상황 Forever</span>', '<span style="color: #e32636">우리 둘이 Forever</span>', '<span style="color: #e32636">첫사랑은 안 이뤄진단</span>', '<span style="color: #e32636">말은 믿지 않기로 해요</span>', '<span style="color: #04a497">익숙함에 속아</span>', '<span style="color: #04a497">잃지 않았으면 해 서로가</span>', '<span style="color: #855fc4">우리라는 말이 지켜질 수 있게</span>', '<span style="color: #f1ce5f">진지한데 뜬금없지만</span>', '<span style="color: #3d72e7">뜬금없지만 Woa</span>']
# <span style="color: #f1ce5f">오늘 난 말야</span>
# lines ['오늘 난 말야']
# new_spans ['<span style="color: #e32636">지금 상황 Forever</span>', '<span style="color: #e32636">우리 둘이 Forever</span>', '<span style="color: #e32636">첫사랑은 안 이뤄진단</span>', '<span style="color: #e32636">말은 믿지 않기로 해요</span>', '<span style="color: #04a497">익숙함에 속아</span>', '<span style="color: #04a497">잃지 않았으면 해 서로가</span>', '<span style="color: #855fc4">우리라는 말이 지켜질 수 있게</span>', '<span style="color: #f1ce5f">진지한데 뜬금없지만</span>', '<span style="color: #3d72e7">뜬금없지만 Woa</span>', '<span style="color: #f1ce5f">오늘 난 말야</span>']
# <span style="color: #ffffff">아주 Nice
# 아주 Nice
# 기분 기분 기분
# Nice
# 아주 Nice</span>
# lines ['아주 Nice', '아주 Nice', '기분 기분 기분', 'Nice', '아주 Nice']
# new_spans ['<span style="color: #ffffff">아주 Nice</span>', '<span style="color: #ffffff">아주 Nice</span>', '<span style="color: #ffffff">기분 기분 기분</span>', '<span style="color: #ffffff">Nice</span>', '<span style="color: #ffffff">아주 Nice</span>']
# <span style="color: #ffffff">오늘 하루도 아주 즐거웠어요
# 다음 데이트도 빨리 했음 좋겠어요
# 집 데려다 주는 길이 너무도 짧아요
# 내일 이 시간에 또 만나요</span>
# lines ['오늘 하루도 아주 즐거웠어요', '다음 데이트도 빨리 했음 좋겠어요', '집 데려다 주는 길이 너무도 짧아요', '내일 이 시간에 또 만나요']
# new_spans ['<span style="color: #ffffff">오늘 하루도 아주 즐거웠어요</span>', '<span style="color: #ffffff">다음 데이트도 빨리 했음 좋겠어요</span>', '<span style="color: #ffffff">집 데려다 주는 길이 너무도 짧아요</span>', '<span style="color: #ffffff">내일 이 시간에 또 만나요</span>']
# <p><span style="color: #63b76c">Four tres two uno uno two</span></p><p><span style="color: #3d72e7">아침엔 모닝콜 필수던 내가</span><br><span style="color: #3d72e7">오늘은 번쩍 번쩍 눈이 떠지는가</span><br><span style="color: #c04737">데이트 날이라 그런지</span><br><span style="color: #c04737">어제 꿈도 좋은 꿈 꿨지</span><br><span style="color: #855fc4">새 신발을 신고</span><br><span style="color: #04a497">현관문을 열고 나가면</span></p><p><span style="color: #f1ce5f">오늘 날씬 너를 많이 닮아</span><br><span style="color: #f1ce5f">너에게 가는 길은 꽃길이 되고</span><br><span style="color: #3d72e7">보일 듯 말 듯한 니 맘 보인다면</span><br><span style="color: #04a497">온몸이 간질간질 두근두근</span><br><span style="color: #df73ff">이 기분은 뭐야 어떡해</span></p><p><span style="color: #ffffff">아주 Nice</span><br><span style="color: #ffffff">아주 Nice</span><br><span style="color: #ffffff">기분 기분 기분</span><br><span style="color: #ffffff">Nice</span><br><span style="color: #ffffff">아주 Nice</span></p><p><span style="color: #63b76c">Four tres two</span></p><p><span style="color: #d962b6">뭐 하나 물어볼게</span><br><span style="color: #d962b6">꿈에서도 너가 둥둥</span><br><span style="color: #d962b6">떠다닐 것 같애?</span><br><span style="color: #63b76c">맞아</span><br><span style="color: #63b76c">멋진 남자 되고파 Fitness</span><br><span style="color: #63b76c">끊은 것 같애?</span><br><span style="color: #d962b6">맞아</span><br><span style="color: #d962b6">연애가 첨이라 내가</span><br><span style="color: #d962b6">긴장할 것 같애?</span><br><span style="color: #63b76c">너가 나의 모든 의문점에</span><br><span style="color: #63b76c">대한 정답인 것 같애</span></p><p><span style="color: #a1dad7">Ah 궁금한 게 있는데</span><br><span style="color: #a1dad7">어떻게 그리 예뻐</span><br><span style="color: #bede0d">신호등만 건너면</span><br><span style="color: #bede0d">맛있는 가게 있어</span><br><span style="color: #bede0d">가자</span></p><p><span style="color: #df73ff">오늘 날씬 너를 많이 닮아</span><br><span style="color: #df73ff">너에게 가는 길은 꽃길이 되고</span><br><span style="color: #3d72e7">보일 듯 말 듯한 니 맘 보인다면</span><br><span style="color: #04a497">온몸이 간질간질 두근두근</span><br><span style="color: #3d72e7">이 기분은 뭐야 어떡해</span><br><span style="color: #3d72e7">뭐야 어떡해</span></p><p><span style="color: #ffffff">아주 Nice</span><br><span style="color: #ffffff">아주 Nice</span><br><span style="color: #ffffff">기분 기분 기분</span><br><span style="color: #ffffff">Nice</span><br><span style="color: #ffffff">아주 Nice</span></p><p><span style="color: #ff7d07">어떤 사람은 말하죠</span><br><span style="color: #ff7d07">연애는 연앨 뿐이라고</span><br><span style="color: #ff7d07">그걸로 끝이라고</span></p><p><span style="color: #4ea8d4">그렇다면 시작점이</span><br><span style="color: #4ea8d4">끝이 될 수 있게</span><br><span style="color: #4ea8d4">너로 시작해 나로 끝낼 수 있게</span><br><span style="color: #4ea8d4">맞잡은 두 손에 원처럼</span><br><span style="color: #4ea8d4">(</span><br><span style="color: #4ea8d4">우린 끝이 없네</span><br><span style="color: #4ea8d4">)</span><br><span style="color: #855fc4">맞잡은 두 손에 원처럼</span><br><span style="color: #855fc4">우린 끝이 없네</span></p><p><span style="color: #e32636">지금 상황 Forever</span><br><span style="color: #e32636">우리 둘이 Forever</span><br><span style="color: #e32636">첫사랑은 안 이뤄진단</span><br><span style="color: #e32636">말은 믿지 않기로 해요</span><br><span style="color: #04a497">익숙함에 속아</span><br><span style="color: #04a497">잃지 않았으면 해 서로가</span><br><span style="color: #855fc4">우리라는 말이 지켜질 수 있게</span><br><span style="color: #f1ce5f">진지한데 뜬금없지만</span><br><span style="color: #3d72e7">뜬금없지만 Woa</span><br><span style="color: #f1ce5f">오늘 난 말야</span></p><p><span style="color: #ffffff">아주 Nice</span><br><span style="color: #ffffff">아주 Nice</span><br><span style="color: #ffffff">기분 기분 기분</span><br><span style="color: #ffffff">Nice</span><br><span style="color: #ffffff">아주 Nice</span></p><p><span style="color: #ffffff">오늘 하루도 아주 즐거웠어요</span><br><span style="color: #ffffff">다음 데이트도 빨리 했음 좋겠어요</span><br><span style="color: #ffffff">집 데려다 주는 길이 너무도 짧아요</span><br><span style="color: #ffffff">내일 이 시간에 또 만나요</span></p>
