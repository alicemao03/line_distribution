# %%
import re
import requests
from bs4 import BeautifulSoup, NavigableString, Tag
import json
import csv
from datetime import datetime

# %%
def get_soup(song):
    url_path = "../json/urls.json"

    with open(url_path, 'r') as file:
        all_urls = json.load(file)

    url = ''
    for u in all_urls:
        if u['name'] == song:
            url = u['url']
            print("url found:", url)
    
    response = requests.get(url)

    soup = BeautifulSoup(response.text, 'html.parser')
    soup = soup.body
    return soup

# %%
def get_color_key(color_key):
    colors = color_key.find_all('span')
    print(colors)
    color_coded_key = {}
    members = []

    for c in colors:
        style = c['style']
        hex = style.split('#')[1]
        name = c.text

        color_coded_key.update({hex: name})
        members.append(name)
    return color_coded_key

# %%
def clean_main_body_html(html_results):
    combined_lines_test = ''
    line = ''

    if not isinstance(html_results, list):
        html_results = list(html_results)

    i = 0
    while i < len(html_results):
        line = html_results[i]
        if isinstance(line, Tag) and line.name == 'p':
            combined_lines_test += '<p>'
            combined_lines_test += clean_main_body_html(line.children)
            combined_lines_test += '</p>'
       

        if isinstance(line, Tag) and line.name == 'br':
            combined_lines_test += str(line)
    

        if isinstance(line, Tag) and line.name == 'span':
            combined_lines_test += str(line)
    
            
        if isinstance(line, NavigableString):
            combine_members = ''

            if line.strip() == '[':
                not_bracket = True
                shared_lyrics = ''

                while not_bracket:
                    i += 1
                    line = html_results[i]
                    if line.name == 'span':
                        hex = line['style'].split('#')[1]
                        combine_members += (' #'+ hex)
                     
                    elif isinstance(line, NavigableString):
                        if "]" in line.strip():
                            shared_lyrics = line.strip().split(']')[1]
                            not_bracket = False
                    
                insert_line = f"<span class='multiple_members' style='color:{combine_members}'>{shared_lyrics}</span>"
                line.insert_before(insert_line)
                combined_lines_test += insert_line
            else:
                combined_lines_test += (' ' + line.strip())
        i += 1
    return combined_lines_test

# %%
def get_color_lyrics_with_container(soup):
    body = soup.find("div", class_="wp-block-group__inner-container is-layout-flow wp-block-group-is-layout-flow")

    find_divs = body.findAll('div', recursive=False)

    color_key = get_color_key(body.find('p', recursive=False))
    main_lyrics_body = find_divs[-1]

    # Hangul lyrics
    find_main_lyrics_body = main_lyrics_body.find_all("div", class_="wp-block-group__inner-container is-layout-flow wp-block-group-is-layout-flow")

    if (len(find_main_lyrics_body) >= 3):
        main_lyrics_body = main_lyrics_body.find_all("div", class_="wp-block-group__inner-container is-layout-flow wp-block-group-is-layout-flow")[1]
        main_lyrics_body = main_lyrics_body.findAll("div")[-1]
        main_lyrics_body = clean_main_body_html(main_lyrics_body)

    else:
        main_lyrics_body = body.find(string='English')
        print(main_lyrics_body.parent)
        tag = main_lyrics_body.parent

        while not tag.name == 'p':
            print(tag)
            tag = tag.parent
        print('parent rag', tag)
        tag = tag.find_next_siblings('p')
        print('next', type(tag))
        
        new_html = []
        for t in tag:
            if not t.name == 'p':
                break
            new_html.append(t)

        main_lyrics_body = clean_main_body_html(new_html)
    return {"color_key": color_key, "main_lyrics_body": main_lyrics_body}

# %%
def get_color_lyrics_with_table(soup):
    body = soup.findAll("table")

    if (len(body) > 1):
        song_header = body[0]
        main_lyrics_body = body[1]
        color_key = get_color_key(song_header.findAll('td')[2])
       
    else:
        main_lyrics_body = body[0]
        song_header = soup.find('div', class_='wp-block-column is-layout-flow wp-block-column-is-layout-flow')
        color_key = get_color_key(song_header.find('p'))

    main_lyrics_body = main_lyrics_body.findAll("td")[1]
    main_lyrics_body = clean_main_body_html(main_lyrics_body.children)
    
    return {"song_header": song_header, "color_key": color_key, "main_lyrics_body": main_lyrics_body}

# %%
def normalize_lyrics(text):
    text = "".join(text.split())
    text = re.sub(r'[\n\(]', ' ', text)
    text = re.sub(r'[^\w\s가-힣]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
def get_raw_color_coded_html(song):
    soup = get_soup(song)

    html_results = []
    if soup.find(('table')) != None:
        html_results = get_color_lyrics_with_table(soup)
    else:
        html_results = get_color_lyrics_with_container(soup)
    
    lyrics = html_results['main_lyrics_body'].strip()

    print('lyrics', lyrics)
    
    p_index = lyrics.find('<p>')
    if p_index:
        print('found p', p_index)
        lyrics = '<p>' + lyrics[:p_index] + '</p>' + lyrics[p_index:]

    color_key = html_results['color_key']
    main_lyrics_body = BeautifulSoup(lyrics, 'html.parser')

    return {'color_key': color_key, 'main_lyrics_body': main_lyrics_body}

# %%
def export_testing_html(html):
    with open('../html/testing.html', 'w') as f:
        f.write(html)

# %%
def get_colored_lyrics(html):

    lyrics = html['main_lyrics_body']
    color_coded_key = html['color_key']

    for br in lyrics.find_all("br"):
        br.decompose()
    
    colored_lyrics = []
    section_num = 0
    line_num = 0
    members = []

    span_lyrics_html = lyrics.find_all('span', recursive=False)

    for s in span_lyrics_html:
        print('something broke', s)


    colored_lyrics_html = lyrics.find_all('p')
    for c in colored_lyrics_html:
        

        line_num = 0
        for line in c:
            text = normalize_lyrics(line.text)
            
            if text:
                if line.name == 'span':
                    members = []
                    hex_re = r"\#([a-zA-Z0-9]{6})"
                    hex_value = re.findall(hex_re, line['style'])

                    for hex in hex_value:
                        print(hex)
                        if hex in color_coded_key:
                            members.append(color_coded_key[hex])
                        else:
                            members = ["SOMETHING BROKE"]
                else:
                    members = ["adlib"]
                colored_lyrics.append({'member': members, 'lyric':line.text, 'section': section_num, 'line': line_num})
                line_num += 1
        section_num += 1
    return colored_lyrics

# %%
html = get_raw_color_coded_html('left & right')
print("html", html['color_key'])
# export_testing_html(str(html['main_lyrics_body']))

get_colored_lyrics(html)
# Out:
# url found: https://colorcodedlyrics.com/2020/06/22/seventeen-left-amp-right/
# song header <div class="wp-block-column is-layout-flow wp-block-column-is-layout-flow">
# <p class="has-text-align-center"><span class="has-inline-color" style="color:#4ea8d4">S.Coups</span>, <span class="has-inline-color" style="color:#e32636">Jeonghan</span>, <span class="has-inline-color" style="color:#df73ff">Joshua</span>, <span class="has-inline-color" style="color:#bede0d">Jun</span>,<br/><span class="has-inline-color" style="color:#c04737">Hoshi</span>, <span class="has-inline-color" style="color:#855fc4">Wonwoo</span>, <span class="has-inline-color" style="color:#ff7d07">Woozi</span>, <span class="has-inline-color" style="color:#3d72e7">DK</span>, <span class="has-inline-color" style="color:#04a497">Mingyu</span>,<br/><span class="has-inline-color" style="color:#a1dad7">THE8</span>, <span class="has-inline-color" style="color:#f1ce5f">Seungkwan</span>, <span class="has-inline-color" style="color:#63b76c">Vernon</span>, <span class="has-inline-color" style="color:#d962b6">Dino</span></p>
# </div>
# [<span class="has-inline-color" style="color:#4ea8d4">S.Coups</span>, <span class="has-inline-color" style="color:#e32636">Jeonghan</span>, <span class="has-inline-color" style="color:#df73ff">Joshua</span>, <span class="has-inline-color" style="color:#bede0d">Jun</span>, <span class="has-inline-color" style="color:#c04737">Hoshi</span>, <span class="has-inline-color" style="color:#855fc4">Wonwoo</span>, <span class="has-inline-color" style="color:#ff7d07">Woozi</span>, <span class="has-inline-color" style="color:#3d72e7">DK</span>, <span class="has-inline-color" style="color:#04a497">Mingyu</span>, <span class="has-inline-color" style="color:#a1dad7">THE8</span>, <span class="has-inline-color" style="color:#f1ce5f">Seungkwan</span>, <span class="has-inline-color" style="color:#63b76c">Vernon</span>, <span class="has-inline-color" style="color:#d962b6">Dino</span>]
# lyrics <p><span style="color: #63b76c">하나 둘 셋 넷</span></p> <p><span style="color: #63b76c">Left and right</span><br/><span style="color: #63b76c">Left and right</span><br/><span style="color: #63b76c">Left and right</span></p> <p><span style="color: #63b76c">Seventeen ha</span></p> <p><span style="color: #e32636">잊지 말아야 해 출발선에 설 때</span><br/><span style="color: #e32636">두 눈 부릅뜨고 고갤 들어</span><br/> Come on!</p> <p><span style="color: #855fc4">무릎 꿇고서 추진력을 얻고 나면</span><br/><span style="color: #855fc4">제일 먼저 Baby 앞서갈래</span><br/> Come on!</p> <p><span style="color: #4ea8d4">친구들 불러 I’ma celebrate</span><br/><span style="color: #4ea8d4">아무도 못 말려 We party today</span><br/><span style="color: #4ea8d4">클라이맥스 달려 꼬리를 휘날려 또</span><br/><span style="color: #4ea8d4">알잖아 버펄로</span></p> <p><span style="color: #04a497">레드 카펫 위를 뛰어</span><br/><span style="color: #04a497">내일은 잘 나갈 거야 더</span><br/><span style="color: #04a497">하물며 대기권을</span><br/><span style="color: #04a497">뚫어 뚫어 뚫어 뚫어</span></p> <p><span style="color: #3d72e7">웃어봐 더 하하하하</span><br/><span style="color: #3d72e7">스무 번 더 하하하하 이것은</span><br/><span style="color: #f1ce5f">결승선을 넘을 때 세리머니</span><br/><span style="color: #f1ce5f">시원하게</span> Yeh it goes like</p> <p><span style="color: #c04737">Left and right</span><br/><span style="color: #c04737">Left and right</span><br/><span style="color: #c04737">Left and right</span><br/><span style="color: #c04737">Rip it Rip it</span></p> <p><span style="color: #bede0d">Left and right</span><br/><span style="color: #bede0d">Left and right</span><br/><span style="color: #bede0d">Left and right</span><br/><span style="color: #bede0d">Rip it Rip it</span></p> <p><span style="color: #ff7d07">기분 좋을 때 걱정 없이</span><br/><span style="color: #ff7d07">더 더 확실하게 Follow me</span><br/> Yeh it goes like</p> <p><span style="color: #a1dad7">Left and right</span><br/><span style="color: #a1dad7">Left and right</span><br/><span style="color: #a1dad7">Left and right</span><br/><span style="color: #a1dad7">Rip it Rip it</span></p> <p><span style="color: #63b76c">I run up I run up</span><br/><span style="color: #63b76c">I run up I run up</span><br/><span style="color: #63b76c">그 누구의 말도 안 들어</span><br/><span style="color: #63b76c">딴말을 떠들어 떠들어</span><br/><span style="color: #63b76c">어쩌고저쩌고 시끄러워 쉿 해</span></p> <p><span style="color: #d962b6">우리에게 필요한 건</span><br/><span style="color: #d962b6">달콤한 내일이잖아</span><br/><span style="color: #d962b6">헹가래 하늘 향해</span><br/><span style="color: #d962b6">위로 위로 위로 위로</span></p> <p><span style="color: #f1ce5f">달리고 달리고 달려봐도</span><br/><span style="color: #f1ce5f">도대체 언제 앞지르냐고</span><br/><span style="color: #f1ce5f">달리는 것만으로도 충분하다고 Yeh</span></p> <p><span style="color: #855fc4">그럼 뭐 어쩌라고</span><br/><span style="color: #855fc4">안 뛰는 것도 방법이라고</span><br/><span style="color: #855fc4">아무렴 어때 Yeh yeh</span></p> <p><span style="color: #a1dad7">웃어봐 더 하하하하</span><br/><span style="color: #a1dad7">스무 번 더 하하하하 이것은</span><br/><span style="color: #c04737">결승선을 넘을 때 세리머니</span><br/><span style="color: #c04737">시원하게</span> Yeh it goes like</p> <p><span style="color: #04a497">Left and right</span><br/><span style="color: #04a497">Left and right</span><br/><span style="color: #04a497">Left and right</span><br/><span style="color: #04a497">Rip it Rip it</span></p> <p><span style="color: #df73ff">Left and right</span><br/><span style="color: #df73ff">Left and right</span><br/><span style="color: #df73ff">Left and right</span><br/><span style="color: #df73ff">Rip it Rip it</span></p> <p><span style="color: #f1ce5f">기분 좋을 때 걱정 없이</span><br/><span style="color: #f1ce5f">더 더 확실하게 Follow me</span><br/> Yeh it goes like</p> <p><span style="color: #d962b6">Left and right</span><br/><span style="color: #d962b6">Left and right</span><br/><span style="color: #d962b6">Left and right</span><br/><span style="color: #d962b6">Rip it Rip it</span></p> <p><span style="color: #e32636">혼자가 아니라</span><br/><span style="color: #e32636">우리 우리라서</span><br/><span style="color: #e32636">겁낼 ...
# html {'4ea8d4': 'S.Coups', 'e32636': 'Jeonghan', 'df73ff': 'Joshua', 'bede0d': 'Jun', 'c04737': 'Hoshi', '855fc4': 'Wonwoo', 'ff7d07': 'Woozi', '3d72e7': 'DK', '04a497': 'Mingyu', 'a1dad7': 'THE8', 'f1ce5f': 'Seungkwan', '63b76c': 'Vernon', 'd962b6': 'Dino'}
# 63b76c
# 63b76c
# 63b76c
# 63b76c
# 63b76c
# e32636
# e32636
# 855fc4
# 855fc4
# 4ea8d4
# 4ea8d4
# 4ea8d4
# 4ea8d4
# 04a497
# 04a497
# 04a497
# 04a497
# 3d72e7
# 3d72e7
# f1ce5f
# f1ce5f
# c04737
# c04737
# c04737
# c04737
# bede0d
# bede0d
# bede0d
# bede0d
# ff7d07
# ff7d07
# a1dad7
# a1dad7
# a1dad7
# a1dad7
# 63b76c
# 63b76c
# 63b76c
# 63b76c
# 63b76c
# d962b6
# d962b6
# d962b6
# d962b6
# f1ce5f
# f1ce5f
# f1ce5f
# 855fc4
# 855fc4
# 855fc4
# a1dad7
# a1dad7
# c04737
# c04737
# 04a497
# 04a497
# 04a497
# 04a497
# df73ff
# df73ff
# df73ff
# df73ff
# f1ce5f
# f1ce5f
# d962b6
# d962b6
# d962b6
# d962b6
# e32636
# e32636
# e32636
# df73ff
# df73ff
# ff7d07
# 3d72e7
# 3d72e7
# 04a497
# 855fc4
# 4ea8d4
# 4ea8d4
# 4ea8d4
# 4ea8d4
# 3d72e7
# 3d72e7
# 3d72e7
# 3d72e7
# df73ff
# df73ff
# bede0d
# bede0d
# bede0d
# bede0d
# 855fc4
# 855fc4
# [{'member': ['Vernon'], 'lyric': '하나 둘 셋 넷', 'section': 0, 'line': 0},
#  {'member': ['Vernon'], 'lyric': 'Left and right', 'section': 1, 'line': 0},
#  {'member': ['Vernon'], 'lyric': 'Left and right', 'section': 1, 'line': 1},
#  {'member': ['Vernon'], 'lyric': 'Left and right', 'section': 1, 'line': 2},
#  {'member': ['Vernon'], 'lyric': 'Seventeen ha', 'section': 2, 'line': 0},
#  {'member': ['Jeonghan'],
#   'lyric': '잊지 말아야 해 출발선에 설 때',
#   'section': 3,
#   'line': 0},
#  {'member': ['Jeonghan'], 'lyric': '두 눈 부릅뜨고 고갤 들어', 'section': 3, 'line': 1},
#  {'member': ['adlib'], 'lyric': ' Come on!', 'section': 3, 'line': 2},
#  {'member': ['Wonwoo'], 'lyric': '무릎 꿇고서 추진력을 얻고 나면', 'section': 4, 'line': 0},
#  {'member': ['Wonwoo'], 'lyric': '제일 먼저 Baby 앞서갈래', 'section': 4, 'line': 1},
#  {'member': ['adlib'], 'lyric': ' Come on!', 'section': 4, 'line': 2},
#  {'member': ['S.Coups'],
#   'lyric': '친구들 불러 I’ma celebrate',
#   'section': 5,
#   'line': 0},
#  {'member': ['S.Coups'],
#   'lyric': '아무도 못 말려 We party today',
#   'section': 5,
#   'line': 1},
#  {'member': ['S.Coups'],
#   'lyric': '클라이맥스 달려 꼬리를 휘날려 또',
#   'section': 5,
#   'line': 2},
#  {'member': ['S.Coups'], 'lyric': '알잖아 버펄로', 'section': 5, 'line': 3},
#  {'member': ['Mingyu'], 'lyric': '레드 카펫 위를 뛰어', 'section': 6, 'line': 0},
#  {'member': ['Mingyu'], 'lyric': '내일은 잘 나갈 거야 더', 'section': 6, 'line': 1},
#  {'member': ['Mingyu'], 'lyric': '하물며 대기권을', 'section': 6, 'line': 2},
#  {'member': ['Mingyu'], 'lyric': '뚫어 뚫어 뚫어 뚫어', 'section': 6, 'line': 3},
#  {'member': ['DK'], 'lyric': '웃어봐 더 하하하하', 'section': 7, 'line': 0},
#  {'member': ['DK'], 'lyric': '스무 번 더 하하하하 이것은', 'section': 7, 'line': 1},
#  {'member': ['Seungkwan'], 'lyric': '결승선을 넘을 때 세리머니', 'section': 7, 'line': 2},
#  {'member': ['Seungkwan'], 'lyric': '시원하게', 'section': 7, 'line': 3},
#  {'member': ['adlib'], 'lyric': ' Yeh it goes like', 'section': 7, 'line': 4},
#  {'member': ['Hoshi'], 'lyric': 'Left and right', 'section': 8, 'line': 0},
#  {'member': ['Hoshi'], 'lyric': 'Left and right', 'section': 8, 'line': 1},
#  {'member': ['Hoshi'], 'lyric': 'Left and right', 'section': 8, 'line': 2},
#  {'member': ['Hoshi'], 'lyric': 'Rip it Rip it', 'section': 8, 'line': 3},
#  {'member': ['Jun'], 'lyric': 'Left and right', 'section': 9, 'line': 0},
#  {'member': ['Jun'], 'lyric': 'Left and right', 'section': 9, 'line': 1},
#  {'member': ['Jun'], 'lyric': 'Left and right', 'section': 9, 'line': 2},
#  {'member': ['Jun'], 'lyric': 'Rip it Rip it', 'section': 9, 'line': 3},
#  {'member': ['Woozi'], 'lyric': '기분 좋을 때 걱정 없이', 'section': 10, 'line': 0},
#  {'member': ['Woozi'],
#   'lyric': '더 더 확실하게 Follow me',
#   'section': 10,
#   'line': 1},
#  {'member': ['adlib'], 'lyric': ' Yeh it goes like', 'section': 10, 'line': 2},
#  {'member': ['THE8'], 'lyric': 'Left and right', 'section': 11, 'line': 0},
#  {'member': ['THE8'], 'lyric': 'Left and right', 'section': 11, 'line': 1},
#  {'member': ['THE8'], 'lyric': 'Left and right', 'section': 11, 'line': 2},
#  {'member': ['THE8'], 'lyric': 'Rip it Rip it', 'section': 11, 'line': 3},
#  {'member': ['Vernon'],
#   'lyric': 'I run up I run up',
#   'section': 12,
#   'line': 0},
#  {'member': ['Vernon'],
#   'lyric': 'I run up I run up',
#   'section': 12,
#   'line': 1},
#  {'member': ['Vernon'], 'lyric': '그 누구의 말도 안 들어', 'section': 12, 'line': 2},
#  {'member': ['Vernon'], 'lyric': '딴말을 떠들어 떠들어', 'section': 12, 'line': 3},
#  {'member': ['Vernon'], 'lyric': '어쩌고저쩌고 시끄러워 쉿 해', 'section': 12, 'line': 4},
#  {'member': ['Dino'], 'lyric': '우리에게 필요한 건', 'section': 13, 'line': 0},
#  {'member': ['Dino'], 'lyric': '달콤한 내일이잖아', 'section': 13, 'line': 1},
#  {'member': ['Dino'], 'lyric': '헹가래 하늘 향해', 'section': 13, 'line': 2},
#  {'member': ['Dino'], 'lyric': '위로 위로 위로 위로', 'section': 13, 'line': 3},
#  {'member': ['Seungkwan'], 'lyric': '달리고 달리고 달려봐도', 'section': 14, 'line': 0},
#  {'member': ['Seungkwan'], 'lyric': '도대체 언제 앞지르냐고', 'section': 14, 'line': 1},
#  {'member': ['Seungkwan'],
#   'lyric': '달리는 것만으로도 충분하다고 Yeh',
#   'section': 14,
#   'line': 2},
#  {'member': ['Wonwoo'], 'lyric': '그럼 뭐 어쩌라고', 'section': 15, 'line': 0},
#  {'member': ['Wonwoo'], 'lyric': '안 뛰는 것도 방법이라고', 'section': 15, 'line': 1},
#  {'member': ['Wonwoo'], 'lyric': '아무렴 어때 Yeh yeh', 'section': 15, 'line': 2},
#  {'member': ['THE8'], 'lyric': '웃어봐 더 하하하하', 'section': 16, 'line': 0},
#  {'member': ['THE8'], 'lyric': '스무 번 더 하하하하 이것은', 'section': 16, 'line': 1},
#  {'member': ['Hoshi'], 'lyric': '결승선을 넘을 때 세리머니', 'section': 16, 'line': 2},
#  {'member': ['Hoshi'], 'lyric': '시원하게', 'section': 16, 'line': 3},
#  {'member': ['adlib'], 'lyric': ' Yeh it goes like', 'section': 16, 'line': 4},
#  {'member': ['Mingyu'], 'lyric': 'Left and right', 'section': 17, 'line': 0},
#  {'member': ['Mingyu'], 'lyric': 'Left and right', 'section': 17, 'line': 1},
#  {'member': ['Mingyu'], 'lyric': 'Left and right', 'section': 17, 'line': 2},
#  {'member': ['Mingyu'], 'lyric': 'Rip it Rip it', 'section': 17, 'line': 3},
#  {'member': ['Joshua'], 'lyric': 'Left and right', 'section': 18, 'line': 0},
#  {'member': ['Joshua'], 'lyric': 'Left and right', 'section': 18, 'line': 1},
#  {'member': ['Joshua'], 'lyric': 'Left and right', 'section': 18, 'line': 2},
#  {'member': ['Joshua'], 'lyric': 'Rip it Rip it', 'section': 18, 'line': 3},
#  {'member': ['Seungkwan'], 'lyric': '기분 좋을 때 걱정 없이', 'section': 19, 'line': 0},
#  {'member': ['Seungkwan'],
#   'lyric': '더 더 확실하게 Follow me',
#   'section': 19,
#   'line': 1},
#  {'member': ['adlib'], 'lyric': ' Yeh it goes like', 'section': 19, 'line': 2},
#  {'member': ['Dino'], 'lyric': 'Left and right', 'section': 20, 'line': 0},
#  {'member': ['Dino'], 'lyric': 'Left and right', 'section': 20, 'line': 1},
#  {'member': ['Dino'], 'lyric': 'Left and right', 'section': 20, 'line': 2},
#  {'member': ['Dino'], 'lyric': 'Rip it Rip it', 'section': 20, 'line': 3},
#  {'member': ['Jeonghan'], 'lyric': '혼자가 아니라', 'section': 21, 'line': 0},
#  {'member': ['Jeonghan'], 'lyric': '우리 우리라서', 'section': 21, 'line': 1},
#  {'member': ['Jeonghan'], 'lyric': '겁낼 필요 없어 Yeh', 'section': 21, 'line': 2},
#  {'member': ['Joshua'], 'lyric': '혼자가 아니라', 'section': 22, 'line': 0},
#  {'member': ['Joshua'], 'lyric': '우리 우리라서', 'section': 22, 'line': 1},
#  {'member': ['Woozi'], 'lyric': '또 걱정 없이 달리지 Yeh', 'section': 22, 'line': 2},
#  {'member': ['DK'], 'lyric': 'So uh', 'section': 23, 'line': 0},
#  {'member': ['DK'], 'lyric': '열정의 세리머니', 'section': 23, 'line': 1},
#  {'member': ['Mingyu'], 'lyric': '넷을 세고 Go 해', 'section': 24, 'line': 0},
#  {'member': ['Wonwoo'], 'lyric': '하나 둘 셋 넷', 'section': 24, 'line': 1},
#  {'member': ['S.Coups'], 'lyric': 'Left and right', 'section': 25, 'line': 0},
#  {'member': ['S.Coups'], 'lyric': 'Left and right', 'section': 25, 'line': 1},
#  {'member': ['S.Coups'], 'lyric': 'Left and right', 'section': 25, 'line': 2},
#  {'member': ['S.Coups'], 'lyric': 'Rip it Rip it', 'section': 25, 'line': 3},
#  {'member': ['DK'], 'lyric': 'Left and right', 'section': 26, 'line': 0},
#  {'member': ['DK'], 'lyric': 'Left and right', 'section': 26, 'line': 1},
#  {'member': ['DK'], 'lyric': 'Left and right', 'section': 26, 'line': 2},
#  {'member': ['DK'], 'lyric': 'Rip it Rip it', 'section': 26, 'line': 3},
#  {'member': ['Joshua'], 'lyric': '같이 가보자 걱정 없이', 'section': 27, 'line': 0},
#  {'member': ['Joshua'],
#   'lyric': '더 더 확실하게 Follow me',
#   'section': 27,
#   'line': 1},
#  {'member': ['adlib'], 'lyric': ' Yeh it goes like', 'section': 27, 'line': 2},
#  {'member': ['Jun'], 'lyric': 'Left and right', 'section': 28, 'line': 0},
#  {'member': ['Jun'], 'lyric': 'Left and right', 'section': 28, 'line': 1},
#  {'member': ['Jun'], 'lyric': 'Left and right', 'section': 28, 'line': 2},
#  {'member': ['Jun'], 'lyric': 'Rip it Rip it', 'section': 28, 'line': 3},
#  {'member': ['Wonwoo'], 'lyric': '하나 둘 셋 넷 둘 둘 셋 넷', 'section': 29, 'line': 0},
#  {'member': ['Wonwoo'], 'lyric': '셋 둘 셋 넷 넷 둘 셋 넷', 'section': 29, 'line': 1}]
